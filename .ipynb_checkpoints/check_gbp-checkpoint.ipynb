# %%
import pandas as pd
import numpy as np
from sqlalchemy import create_engine
engine = create_engine("mysql+pymysql://rex:#Pass123@localhost/rex_history")
sql = "SELECT * FROM `gbpusd_h` ORDER BY `index` ASC"
gbp = pd.read_sql(sql, engine, index_col="index")

# %%
gbp.index
# Out:
# DatetimeIndex(['2019-01-01 17:00:00', '2019-01-01 18:00:00',
#                '2019-01-01 19:00:00', '2019-01-01 20:00:00',
#                '2019-01-01 21:00:00', '2019-01-01 22:00:00',
#                '2019-01-01 23:00:00', '2019-01-02 00:00:00',
#                '2019-01-02 01:00:00', '2019-01-02 02:00:00',
#                ...
#                '2020-12-31 07:00:00', '2020-12-31 08:00:00',
#                '2020-12-31 09:00:00', '2020-12-31 10:00:00',
#                '2020-12-31 11:00:00', '2020-12-31 12:00:00',
#                '2020-12-31 13:00:00', '2020-12-31 14:00:00',
#                '2020-12-31 15:00:00', '2020-12-31 16:00:00'],
#               dtype='datetime64[ns]', name='index', length=12442, freq=None)

# %%
gbp.head()
# Out:
#                         open     high      low    close  bodysize  volume  \
# index
# 2019-01-01 17:00:00  1.27459  1.27478  1.27227  1.27346   0.00113       0
# 2019-01-01 18:00:00  1.27346  1.27544  1.27317  1.27528   0.00182       0
# 2019-01-01 19:00:00  1.27528  1.27528  1.27448  1.27483   0.00045       0
# 2019-01-01 20:00:00  1.27482  1.27483  1.27412  1.27449   0.00033       0
# 2019-01-01 21:00:00  1.27449  1.27449  1.27229  1.27278   0.00171       0
#
#                     direction
# index
# 2019-01-01 17:00:00      down
# 2019-01-01 18:00:00        up
# 2019-01-01 19:00:00      down
# 2019-01-01 20:00:00      down
# 2019-01-01 21:00:00      down

# %%
gbp.drop("volume", axis=1, inplace=True)

# %%
gbp.head()
# Out:
#                  index     open     high      low    close  bodysize direction
# 0  2019-01-01 17:00:00  1.27459  1.27478  1.27227  1.27346   0.00113      down
# 1  2019-01-01 18:00:00  1.27346  1.27544  1.27317  1.27528   0.00182        up
# 2  2019-01-01 19:00:00  1.27528  1.27528  1.27448  1.27483   0.00045      down
# 3  2019-01-01 20:00:00  1.27482  1.27483  1.27412  1.27449   0.00033      down
# 4  2019-01-01 21:00:00  1.27449  1.27449  1.27229  1.27278   0.00171      down

# %%
gbp.index
# Out:
# RangeIndex(start=0, stop=12442, step=1)

# %%
gbp["index"]
# Out:
# 0        2019-01-01 17:00:00
# 1        2019-01-01 18:00:00
# 2        2019-01-01 19:00:00
# 3        2019-01-01 20:00:00
# 4        2019-01-01 21:00:00
#                 ...
# 12437    2020-12-31 12:00:00
# 12438    2020-12-31 13:00:00
# 12439    2020-12-31 14:00:00
# 12440    2020-12-31 15:00:00
# 12441    2020-12-31 16:00:00
# Name: index, Length: 12442, dtype: object

# %%
gbp.set_index("index", inplace=True)

# %%
gbp.head()
# Out:
#                         open     high      low    close  bodysize direction
# index
# 2019-01-01 17:00:00  1.27459  1.27478  1.27227  1.27346   0.00113      down
# 2019-01-01 18:00:00  1.27346  1.27544  1.27317  1.27528   0.00182        up
# 2019-01-01 19:00:00  1.27528  1.27528  1.27448  1.27483   0.00045      down
# 2019-01-01 20:00:00  1.27482  1.27483  1.27412  1.27449   0.00033      down
# 2019-01-01 21:00:00  1.27449  1.27449  1.27229  1.27278   0.00171      down

# %%
import rex

# %%
sma = rex.get_sma(gbp)

# %%
list(sma.values())[:5]
# Out:
# [1.274168, 1.274076, 1.2736819999999998, 1.273828, 1.274028]

# %%
macd = rex.get_macd(gbp)

# %%
macd_df = pd.DataFrame.from_dict(macd, orient="index")
macd_df.head()
# Out:
#                          macd    signal
# 2019-01-03 02:00:00 -0.379635 -0.315904
# 2019-01-03 03:00:00 -0.373863 -0.327496
# 2019-01-03 04:00:00 -0.365040 -0.335005
# 2019-01-03 05:00:00 -0.353939 -0.338792
# 2019-01-03 06:00:00 -0.341191 -0.339271

# %%
macd_df.index = pd.to_datetime(macd_df.index, format ='%Y-%m-%d %H:%M:%S')

# %%
x = [list(macd_df.index)[5]]
x
# Out:
# [Timestamp('2019-01-03 07:00:00')]

# %%
macd_df.loc[x]
# Out:
#                          macd    signal
# 2019-01-03 07:00:00 -0.327295 -0.336876

# %%
gbp.loc[x]
# Out:
#                         open     high      low     close  bodysize direction
# index
# 2019-01-03 07:00:00  1.25581  1.25706  1.25509 -0.327295    0.0002        up

# %%
gbp.append(macd_df).loc[x]
# Out:
#                         open     high      low     close  bodysize direction  \
# 2019-01-03 07:00:00  1.25581  1.25706  1.25509 -0.327295    0.0002        up
# 2019-01-03 07:00:00      NaN      NaN      NaN       NaN       NaN       NaN
#
#                          macd    signal
# 2019-01-03 07:00:00       NaN       NaN
# 2019-01-03 07:00:00 -0.327295 -0.336876

# %%
list(gbp.index)[5]
# Out:
# '2019-01-01 22:00:00'

# %%
gbp.index = pd.to_datetime(gbp.index, format ='%Y-%m-%d %H:%M:%S')

# %%
gbp.tail()
# Out:
#                         open     high      low     close  bodysize direction
# index
# 2020-12-31 12:00:00  1.36630  1.36783  1.36493  0.000057   0.00129      down
# 2020-12-31 13:00:00  1.36498  1.36619  1.36498  0.000023   0.00086        up
# 2020-12-31 14:00:00  1.36584  1.36748  1.36529 -0.000006   0.00085        up
# 2020-12-31 15:00:00  1.36666  1.36755  1.36616 -0.000027   0.00089        up
# 2020-12-31 16:00:00  1.36755  1.36787  1.36606 -0.000051   0.00123      down

# %%
gbp["macd"] = macd_df["macd"]

# %%
gbp["macd_signal"] = macd_df["signal"]

# %%
gbp.loc[x]
# Out:
#                         open     high      low     close  bodysize direction  \
# index
# 2019-01-03 07:00:00  1.25581  1.25706  1.25509 -0.327295    0.0002        up
#
#                          macd  macd_signal
# index
# 2019-01-03 07:00:00 -0.327295    -0.336876

# %%
gbp.tail()
# Out:
#                         open     high      low     close  bodysize direction  \
# index
# 2020-12-31 12:00:00  1.36630  1.36783  1.36493  0.000057   0.00129      down
# 2020-12-31 13:00:00  1.36498  1.36619  1.36498  0.000023   0.00086        up
# 2020-12-31 14:00:00  1.36584  1.36748  1.36529 -0.000006   0.00085        up
# 2020-12-31 15:00:00  1.36666  1.36755  1.36616 -0.000027   0.00089        up
# 2020-12-31 16:00:00  1.36755  1.36787  1.36606 -0.000051   0.00123      down
#
#                          macd  macd_signal
# index
# 2020-12-31 12:00:00  0.000057     0.000154
# 2020-12-31 13:00:00  0.000023     0.000128
# 2020-12-31 14:00:00 -0.000006     0.000101
# 2020-12-31 15:00:00 -0.000027     0.000076
# 2020-12-31 16:00:00 -0.000051     0.000050

# %%
gbp.index.shift(1, freq="H")
# Out:
# DatetimeIndex(['2019-01-01 18:00:00', '2019-01-01 19:00:00',
#                '2019-01-01 20:00:00', '2019-01-01 21:00:00',
#                '2019-01-01 22:00:00', '2019-01-01 23:00:00',
#                '2019-01-02 00:00:00', '2019-01-02 01:00:00',
#                '2019-01-02 02:00:00', '2019-01-02 03:00:00',
#                ...
#                '2020-12-31 08:00:00', '2020-12-31 09:00:00',
#                '2020-12-31 10:00:00', '2020-12-31 11:00:00',
#                '2020-12-31 12:00:00', '2020-12-31 13:00:00',
#                '2020-12-31 14:00:00', '2020-12-31 15:00:00',
#                '2020-12-31 16:00:00', '2020-12-31 17:00:00'],
#               dtype='datetime64[ns]', name='index', length=12442, freq=None)

# %%
gbp.head()
# Out:
#                         open     high      low    close  bodysize direction  \
# index
# 2019-01-01 17:00:00  1.27459  1.27478  1.27227  1.27346   0.00113      down
# 2019-01-01 18:00:00  1.27346  1.27544  1.27317  1.27528   0.00182        up
# 2019-01-01 19:00:00  1.27528  1.27528  1.27448  1.27483   0.00045      down
# 2019-01-01 20:00:00  1.27482  1.27483  1.27412  1.27449   0.00033      down
# 2019-01-01 21:00:00  1.27449  1.27449  1.27229  1.27278   0.00171      down
#
#                      macd  macd_signal
# index
# 2019-01-01 17:00:00   NaN          NaN
# 2019-01-01 18:00:00   NaN          NaN
# 2019-01-01 19:00:00   NaN          NaN
# 2019-01-01 20:00:00   NaN          NaN
# 2019-01-01 21:00:00   NaN          NaN

# %%
dir(rex)
# Out:
# ['__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'average',
#  'check_for_patterns',
#  'final',
#  'get_adx',
#  'get_atr',
#  'get_bollinger',
#  'get_double_candlestick_patterns',
#  'get_ema',
#  'get_harmonic',
#  'get_heikin_ashi',
#  'get_keltner',
#  'get_macd',
#  'get_parabolic_sar',
#  'get_pp_daily',
#  'get_rsi',
#  'get_single_candlestick_patterns',
#  'get_sma',
#  'get_smoothed_turns',
#  'get_stochastic',
#  'get_triple_candlestick_patterns',
#  'get_turns',
#  'get_williams_r',
#  'pd',
#  'pp',
#  'time']

# %%
singles = rex.get_single_candlestick_patterns(gbp)
# Out:
# 2019-01-01 17:00:00 False True False
# 2019-01-01 18:00:00 False True False
# 2019-01-01 19:00:00 True True False
# 2019-01-01 20:00:00 True True False
# 2019-01-01 21:00:00 False True False
# 2019-01-01 22:00:00 True True False
# 2019-01-01 23:00:00 True True False
# 2019-01-02 00:00:00 False True False
# 2019-01-02 01:00:00 True False True
# 2019-01-02 02:00:00 True False False
# 2019-01-02 03:00:00 False True False
# 2019-01-02 04:00:00 False True False
# 2019-01-02 05:00:00 False True False
# 2019-01-02 06:00:00 False True False
# 2019-01-02 07:00:00 False True False
# 2019-01-02 08:00:00 False True False
# 2019-01-02 09:00:00 True False True
# 2019-01-02 10:00:00 True False False
# 2019-01-02 11:00:00 True False True
# 2019-01-02 12:00:00 False True False
# 2019-01-02 13:00:00 True True False
# 2019-01-02 14:00:00 False True False
# 2019-01-02 15:00:00 True False True
# 2019-01-02 16:00:00 True True False
# 2019-01-02 17:00:00 False True False
# ...

# %%
singles.keys()
# Out:
# dict_keys(['hammers', 'ihammers'])

# %%
all_singles = []
for x in singles.keys():
    all_singles = all_singles + singles[x]

all_singles = set(all_singles)
all_singles = sorted(list(all_singles))
singles_series = pd.Series(dtype="float")
for x in range(len(gbp)):
    if gbp.iloc[x].name in all_singles:
        singles_series.loc[gbp.iloc[x].name] = 1
    else:
        singles_series.loc[gbp.iloc[x].name] = 0

# %%
gbp.insert(len(gbp.columns), "singles", singles_series)

# %%
gbp.head()
# Out:
#                         open     high      low    close  bodysize direction  \
# index
# 2019-01-01 17:00:00  1.27459  1.27478  1.27227  1.27346   0.00113      down
# 2019-01-01 18:00:00  1.27346  1.27544  1.27317  1.27528   0.00182        up
# 2019-01-01 19:00:00  1.27528  1.27528  1.27448  1.27483   0.00045      down
# 2019-01-01 20:00:00  1.27482  1.27483  1.27412  1.27449   0.00033      down
# 2019-01-01 21:00:00  1.27449  1.27449  1.27229  1.27278   0.00171      down
#
#                      macd  macd_signal  singles
# index
# 2019-01-01 17:00:00   NaN          NaN        0
# 2019-01-01 18:00:00   NaN          NaN        0
# 2019-01-01 19:00:00   NaN          NaN        0
# 2019-01-01 20:00:00   NaN          NaN        0
# 2019-01-01 21:00:00   NaN          NaN        0

# %%
gbp
# Out:
#                         open     high      low     close  bodysize direction  \
# 2020-12-31 12:00:00  1.36630  1.36783  1.36493  0.000057   0.00129      down
# 2020-12-31 13:00:00  1.36498  1.36619  1.36498  0.000023   0.00086        up
# 2020-12-31 14:00:00  1.36584  1.36748  1.36529 -0.000006   0.00085        up
# 2020-12-31 15:00:00  1.36666  1.36755  1.36616 -0.000027   0.00089        up
# 2020-12-31 16:00:00  1.36755  1.36787  1.36606 -0.000051   0.00123      down
#
#                          macd  macd_signal  singles  level_1  level_2  \
# 2020-12-31 12:00:00  0.000057     0.000154        0  1.35084  1.35462
# 2020-12-31 13:00:00  0.000023     0.000128        0  1.35084  1.35462
# 2020-12-31 14:00:00 -0.000006     0.000101        0  1.35084  1.35462
# 2020-12-31 15:00:00 -0.000027     0.000076        0  1.35084  1.35462
# 2020-12-31 16:00:00 -0.000051     0.000050        0  1.35084  1.35462
#
#                      level_3  level_4  level_5
# ...

# %%
# %%time
tp = rex.get_turns(gbp)
# Out:
# Wall time: 10.4 s

# %%
tp
# Out:
# {'2019-01-01 21:00:00': 'up',
#  '2019-01-02 01:00:00': 'down',
#  '2019-01-02 13:00:00': 'up',
#  '2019-01-02 15:00:00': 'down',
#  '2019-01-02 17:00:00': 'up',
#  '2019-01-03 04:00:00': 'down',
#  '2019-01-03 06:00:00': 'up',
#  '2019-01-03 12:00:00': 'down',
#  '2019-01-03 18:00:00': 'up',
#  '2019-01-03 23:00:00': 'down',
#  '2019-01-04 01:00:00': 'up',
#  '2019-01-04 06:00:00': 'down',
#  '2019-01-04 09:00:00': 'up',
#  '2019-01-04 14:00:00': 'down',
#  '2019-01-04 16:00:00': 'up',
#  '2019-01-07 00:00:00': 'down',
#  '2019-01-07 04:00:00': 'up',
#  '2019-01-07 10:00:00': 'down',
#  '2019-01-07 12:00:00': 'up',
#  '2019-01-07 19:00:00': 'down',
#  '2019-01-07 22:00:00': 'up',
#  '2019-01-08 04:00:00': 'down',
#  '2019-01-08 14:00:00': 'up',
#  '2019-01-08 23:00:00': 'down',
#  '2019-01-09 02:00:00': 'up',
#  '2019-01-09 03:00:00': 'down',
#  '2019-01-09 05:00:00': 'up',
#  '2019-01-09 16:00:00': 'down',
#  '2019-01-09 22:00:00': 'up',
#  '2019-01-09 23:00:00': 'down',
# ...

# %%
tp_keys = sorted(list(tp.keys()))
level_dict = {}
for index, row in gbp.iterrows():
    stop_point = tp_keys[0]
    stop_point = next((x for x in tp_keys if x > index ), None)
    if stop_point:
        tp_index = tp_keys.index(stop_point)
        if tp_index > 4:
            level_list = []
            working_keys = tp_keys[tp_index-5:tp_index]
            for some_key in working_keys:
                #getting the 5 levels, dependent on movement of turn
                if tp[some_key] == "up":
                    level_list.append(min([float(gbp.loc[some_key, "open"]), float(gbp.loc[some_key, "close"])]))
                else:
                    level_list.append(max([float(gbp.loc[some_key, "open"]), float(gbp.loc[some_key, "close"])]))
            level_dict[index] = {"level_1": level_list[0],
                                 "level_2": level_list[1],
                                 "level_3": level_list[2],
                                 "level_4": level_list[3],
                                 "level_5": level_list[4]}
    else:
        level_list = []
        working_keys = tp_keys[-5:]
        for some_key in working_keys:
            #getting the 5 levels, dependent on movement of turn
            if tp[some_key] == "up":
                level_list.append(min([float(gbp.loc[some_key, "open"]), float(gbp.loc[some_key, "close"])]))
            else:
                level_list.append(max([float(gbp.loc[some_key, "open"]), float(gbp.loc[some_key, "close"])]))
        level_dict[index] = {"level_1": level_list[0],
                             "level_2": level_list[1],
                             "level_3": level_list[2],
                             "level_4": level_list[3],
                             "level_5": level_list[4]}

tp_levels_df = pd.DataFrame.from_dict(level_dict, orient="index")

# %%
temp_gbp = pd.concat([gbp, tp_levels_df], axis=1)

# %%
temp_gbp.tail()
# Out:
#                         open     high      low    close  bodysize direction  \
# 2020-12-31 12:00:00  1.36630  1.36783  1.36493  1.36501   0.00129      down
# 2020-12-31 13:00:00  1.36498  1.36619  1.36498  1.36584   0.00086        up
# 2020-12-31 14:00:00  1.36584  1.36748  1.36529  1.36669   0.00085        up
# 2020-12-31 15:00:00  1.36666  1.36755  1.36616  1.36755   0.00089        up
# 2020-12-31 16:00:00  1.36755  1.36787  1.36606  1.36632   0.00123      down
#
#                           pp  standard_r1  standard_s1    fib_r1    fib_s1  \
# 2020-12-31 12:00:00  1.35969      1.36663      1.35446  1.364339  1.355041
# 2020-12-31 13:00:00  1.35969      1.36663      1.35446  1.364339  1.355041
# 2020-12-31 14:00:00  1.35969      1.36663      1.35446  1.364339  1.355041
# 2020-12-31 15:00:00  1.35969      1.36663      1.35446  1.364339  1.355041
# 2020-12-31 16:00:00  1.35969      1.36663      1.35446  1.364339  1.355041
#
# ...

# %%
temp_gbp.tail()
# Out:
#                         open     high      low    close  bodysize direction  \
# 2020-12-31 12:00:00  1.36630  1.36783  1.36493  1.36501   0.00129      down
# 2020-12-31 13:00:00  1.36498  1.36619  1.36498  1.36584   0.00086        up
# 2020-12-31 14:00:00  1.36584  1.36748  1.36529  1.36669   0.00085        up
# 2020-12-31 15:00:00  1.36666  1.36755  1.36616  1.36755   0.00089        up
# 2020-12-31 16:00:00  1.36755  1.36787  1.36606  1.36632   0.00123      down
#
#                      level_1  level_2  level_3  level_4  level_5
# 2020-12-31 12:00:00  1.36286  1.36182  1.36587  1.36481  1.36710
# 2020-12-31 13:00:00  1.36182  1.36587  1.36481  1.36710  1.36498
# 2020-12-31 14:00:00  1.36182  1.36587  1.36481  1.36710  1.36498
# 2020-12-31 15:00:00  1.36182  1.36587  1.36481  1.36710  1.36498
# 2020-12-31 16:00:00  1.36182  1.36587  1.36481  1.36710  1.36498

# %%
#Pivot Points, have to pass dict of previous day
#get df of previous day

from sqlalchemy import create_engine
engine = create_engine("mysql+pymysql://rex:#Pass123@localhost/rex_history")
sql = "SELECT * FROM `gbpusd_d` ORDER BY `index` ASC"
gbp_d = pd.read_sql(sql, engine, index_col="index")

# %%
gbp_d.head()
# Out:
#                open     high      low    close  bodysize  volume direction
# index
# 2019-01-01  1.27459  1.27544  1.27227  1.27331   0.00128       0      down
# 2019-01-02  1.27334  1.27729  1.24250  1.25480   0.01854       0      down
# 2019-01-03  1.25481  1.26472  1.25385  1.26367   0.00886       0        up
# 2019-01-04  1.26368  1.27443  1.26166  1.27170   0.00802       0        up
# 2019-01-06  1.27187  1.27506  1.27113  1.27447   0.00260       0        up

# %%
gbp_d.index
# Out:
# DatetimeIndex(['2020-12-31', '2020-12-30', '2020-12-29', '2020-12-28',
#                '2020-12-27', '2020-12-25', '2020-12-24', '2020-12-23',
#                '2020-12-22', '2020-12-21',
#                ...
#                '2019-01-11', '2019-01-10', '2019-01-09', '2019-01-08',
#                '2019-01-07', '2019-01-06', '2019-01-04', '2019-01-03',
#                '2019-01-02', '2019-01-01'],
#               dtype='datetime64[ns]', name='index', length=626, freq=None)

# %%
random_day = list(gbp_d.index)[78]

# %%
my_dict = {"high": gbp_d.loc[random_day, "high"],
           "low": gbp_d.loc[random_day, "low"],
           "open": gbp_d.loc[random_day, "open"],
           "close": gbp_d.loc[random_day, "close"],}

# %%
my_dict
# Out:
# {'high': 1.29782, 'low': 1.28191, 'open': 1.29354, 'close': 1.28623}

# %%
pp = rex.get_pp_daily(my_dict)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15316/3667381888.py in <module>
# ----> 1 pp = rex.get_pp_daily(my_dict)
#
# ~\OneDrive\projects\rex\rex.py in get_pp_daily(dict)
#    1088
#    1089
# -> 1090         high = yester_dict["high"]
#    1091         low = yester_dict["low"]
#    1092         close = yester_dict["close"]
#
# ~\OneDrive\projects\rex\env\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     612         elif isinstance(data, dict):
#     613             # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 614             mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     615         elif isinstance(data, ma.MaskedArray):
#     616             import numpy.ma.mrecords as mrecords
#
# ...

# %%
import rex

# %%
pp = rex.get_pp_daily(my_dict)

# %%
import importlib
importlib.reload(rex)
# Out:
# <module 'rex' from 'C:\\Users\\dimad\\OneDrive\\projects\\rex\\rex.py'>

# %%
pp
# Out:
# {'daily': {'standard': {'pp': 1.2886533333333334,
#    'r1': 1.2953966666666668,
#    'r2': 1.3045633333333333,
#    'r3': 1.3113066666666666,
#    's1': 1.2794866666666669,
#    's2': 1.2727433333333336,
#    's3': 1.263576666666667},
#   'woodie': {'pp': 1.2880475,
#    'r1': 1.294185,
#    'r2': 1.3039574999999999,
#    's1': 1.278275,
#    's2': 1.2721375000000001},
#   'camarilla': {'pp': 1.2886533333333334,
#    'r1': 1.3034653029999999,
#    'r2': 1.3047906059999999,
#    'r3': 1.3061174999999998,
#    'r4': 1.3100949999999998,
#    's1': 1.2689946970000001,
#    's2': 1.2676693940000001,
#    's3': 1.2663425000000001,
#    's4': 1.2623650000000002},
#   'fibonacci': {'pp': 1.2886533333333334,
#    'r1': 1.2947309533333333,
#    'r2': 1.2984857133333334,
#    'r3': 1.3045633333333333,
#    's1': 1.2825757133333335,
#    's2': 1.2788209533333335,
#    's3': 1.2727433333333336}}}

# %%
random_hour = list(gbp.index)[78]

# %%
gbp.index
# Out:
# Index(['2019-01-01 17:00:00', '2019-01-01 18:00:00', '2019-01-01 19:00:00',
#        '2019-01-01 20:00:00', '2019-01-01 21:00:00', '2019-01-01 22:00:00',
#        '2019-01-01 23:00:00', '2019-01-02 00:00:00', '2019-01-02 01:00:00',
#        '2019-01-02 02:00:00',
#        ...
#        '2020-12-31 07:00:00', '2020-12-31 08:00:00', '2020-12-31 09:00:00',
#        '2020-12-31 10:00:00', '2020-12-31 11:00:00', '2020-12-31 12:00:00',
#        '2020-12-31 13:00:00', '2020-12-31 14:00:00', '2020-12-31 15:00:00',
#        '2020-12-31 16:00:00'],
#       dtype='object', name='index', length=12442)

# %%
str(random_hour)
# Out:
# '2019-01-06 23:00:00'

# %%
gbp_d.loc[pd.to_datetime(str(random_hour).split(' ')[0], format='%Y-%m-%d')]
# Out:
# open         1.27187
# high         1.27506
# low          1.27113
# close        1.27447
# bodysize      0.0026
# volume             0
# direction         up
# Name: 2019-01-06 00:00:00, dtype: object

# %%
# Out:
# Empty DataFrame
# Columns: [open, high, low, close, bodysize, volume, direction]
# Index: []

# %%
random_day
# Out:
# Timestamp('2020-10-01 00:00:00')

# %%
random_hour
# Out:
# Timestamp('2019-01-06 23:00:00')

# %%
import datetime

# %%
random_hour - datetime.timedelta(days=1)
# Out:
# Timestamp('2019-01-05 23:00:00')

# %%
dir(random_hour)
# Out:
# ['__add__',
#  '__array_priority__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__pyx_vtable__',
#  '__radd__',
#  '__reduce__',
#  '__reduce_cython__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rsub__',
#  '__setattr__',
#  '__setstate__',
#  '__setstate_cython__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__weakref__',
#  '_date_repr',
#  '_freq',
#  '_freqstr',
#  '_repr_base',
#  '_round',
#  '_set_freq',
#  '_short_repr',
#  '_time_repr',
#  'asm8',
#  'astimezone',
#  'ceil',
#  'combine',
#  'ctime',
#  'date',
#  'day',
#  'day_name',
#  'day_of_week',
#  'day_of_year',
#  'dayofweek',
#  'dayofyear',
#  'days_in_month',
#  'daysinmonth',
#  'dst',
#  'floor',
#  'fold',
#  'freq',
#  'freqstr',
# ...

# %%
random_hour.day
# Out:
# 6

# %%
pd.to_datetime(random_hour).date()
# Out:
# datetime.date(2019, 1, 6)

# %%
pd.Timestamp(pd.to_datetime(random_hour).date()) - datetime.timedelta(days=1)
# Out:
# Timestamp('2019-01-05 00:00:00')

# %%
import rex
from sqlalchemy import create_engine
engine = create_engine("mysql+pymysql://rex:#Pass123@localhost/rex_history")
sql = "SELECT * FROM `gbpusd_d` ORDER BY `index` ASC"
gbp_d = pd.read_sql(sql, engine, index_col="index")
daily_keys = sorted(list(gbp_d.index))

pp_dict = {}
for index, row in gbp.iterrows():
    today_index = daily_keys.index(pd.Timestamp(pd.to_datetime(index).date()))
    if today_index > 0:
        yesterday = daily_keys[today_index-1]
        yesterdict = {"open": gbp_d.loc[yesterday, "open"],
                      "high": gbp_d.loc[yesterday, "high"],
                      "low": gbp_d.loc[yesterday, "low"],
                      "close": gbp_d.loc[yesterday, "close"]}
        all_pp = rex.get_pp_daily(yesterdict)
        pp_dict[index] = {"pp" : all_pp["daily"]["standard"]["pp"],
                          "standard_r1" : all_pp["daily"]["standard"]["r1"],
                          "standard_s1" : all_pp["daily"]["standard"]["s1"],
                          "fib_r1" : all_pp["daily"]["fibonacci"]["r1"],
                          "fib_s1" : all_pp["daily"]["fibonacci"]["s1"],}

pp_df = pd.DataFrame.from_dict(pp_dict,orient='index')
gbp = pd.concat([gbp, pp_df], axis=1)

# %%
gbp.tail()
# Out:
#                         open     high      low    close  bodysize  volume  \
# 2020-12-31 12:00:00  1.36630  1.36783  1.36493  1.36501   0.00129       0
# 2020-12-31 13:00:00  1.36498  1.36619  1.36498  1.36584   0.00086       0
# 2020-12-31 14:00:00  1.36584  1.36748  1.36529  1.36669   0.00085       0
# 2020-12-31 15:00:00  1.36666  1.36755  1.36616  1.36755   0.00089       0
# 2020-12-31 16:00:00  1.36755  1.36787  1.36606  1.36632   0.00123       0
#
#                     direction       pp  standard_r1  standard_s1    fib_r1  \
# 2020-12-31 12:00:00      down  1.35969      1.36663      1.35446  1.364339
# 2020-12-31 13:00:00        up  1.35969      1.36663      1.35446  1.364339
# 2020-12-31 14:00:00        up  1.35969      1.36663      1.35446  1.364339
# 2020-12-31 15:00:00        up  1.35969      1.36663      1.35446  1.364339
# 2020-12-31 16:00:00      down  1.35969      1.36663      1.35446  1.364339
#
#                        fib_s1
# 2020-12-31 12:00:00  1.355041
# ...

# %%
gbp_d.loc[pd.to_datetime(str(random_hour).split(' ')[0], format='%Y-%m-%d')]
# Out:
# open         1.27187
# high         1.27506
# low          1.27113
# close        1.27447
# bodysize      0.0026
# volume             0
# direction         up
# Name: 2019-01-06 00:00:00, dtype: object

# %%
sma_5 = rex.get_sma(gbp, fac=5)
sma_10 = rex.get_sma(gbp, fac=10)

# %%
sma_5_s = pd.Series(sma_5)

# %%
pd.concat([gbp, sma_5_s.to_frame("sma_5")], axis=1).head()
# Out:
#                         open     high      low    close  bodysize direction  \
# 2019-01-01 17:00:00  1.27459  1.27478  1.27227  1.27346   0.00113      down
# 2019-01-01 18:00:00  1.27346  1.27544  1.27317  1.27528   0.00182        up
# 2019-01-01 19:00:00  1.27528  1.27528  1.27448  1.27483   0.00045      down
# 2019-01-01 20:00:00  1.27482  1.27483  1.27412  1.27449   0.00033      down
# 2019-01-01 21:00:00  1.27449  1.27449  1.27229  1.27278   0.00171      down
#
#                      pp  standard_r1  standard_s1  fib_r1  fib_s1     sma_5
# 2019-01-01 17:00:00 NaN          NaN          NaN     NaN     NaN       NaN
# 2019-01-01 18:00:00 NaN          NaN          NaN     NaN     NaN       NaN
# 2019-01-01 19:00:00 NaN          NaN          NaN     NaN     NaN       NaN
# 2019-01-01 20:00:00 NaN          NaN          NaN     NaN     NaN       NaN
# 2019-01-01 21:00:00 NaN          NaN          NaN     NaN     NaN  1.274168

# %%
for ma in [5 ,10]:
    sma = rex.get_sma(gbp, ma)
    ema = rex.get_ema(gbp, ma)
    gbp = pd.concat([gbp, pd.Series(sma).to_frame(f"sma{ma}"), pd.Series(ema).to_frame(f"ema{ma}")], axis=1)

# %%
gbp.columns
# Out:
# Index(['open', 'high', 'low', 'close', 'bodysize', 'direction', 'pp',
#        'standard_r1', 'standard_s1', 'fib_r1', 'fib_s1', 'sma5', 'ema5',
#        'sma10', 'ema10'],
#       dtype='object')

# %%
gbp.tail()
# Out:
#                         open     high      low    close  bodysize direction  \
# 2020-12-31 12:00:00  1.36630  1.36783  1.36493  1.36501   0.00129      down
# 2020-12-31 13:00:00  1.36498  1.36619  1.36498  1.36584   0.00086        up
# 2020-12-31 14:00:00  1.36584  1.36748  1.36529  1.36669   0.00085        up
# 2020-12-31 15:00:00  1.36666  1.36755  1.36616  1.36755   0.00089        up
# 2020-12-31 16:00:00  1.36755  1.36787  1.36606  1.36632   0.00123      down
#
#                           pp  standard_r1  standard_s1    fib_r1    fib_s1  \
# 2020-12-31 12:00:00  1.35969      1.36663      1.35446  1.364339  1.355041
# 2020-12-31 13:00:00  1.35969      1.36663      1.35446  1.364339  1.355041
# 2020-12-31 14:00:00  1.35969      1.36663      1.35446  1.364339  1.355041
# 2020-12-31 15:00:00  1.35969      1.36663      1.35446  1.364339  1.355041
# 2020-12-31 16:00:00  1.35969      1.36663      1.35446  1.364339  1.355041
#
# ...

# %%
bb = rex.get_bollinger(gbp)

# %%
bb
# Out:
# {Timestamp('2019-01-02 12:00:00'): {'center': 1.2691019999999997,
#   'upper': 1.2815354296407537,
#   'lower': 1.2566685703592457},
#  Timestamp('2019-01-02 13:00:00'): {'center': 1.2683879999999998,
#   'upper': 1.281394567733669,
#   'lower': 1.2553814322663306},
#  Timestamp('2019-01-02 14:00:00'): {'center': 1.2676815,
#   'upper': 1.2806467771501016,
#   'lower': 1.2547162228498983},
#  Timestamp('2019-01-02 15:00:00'): {'center': 1.2669944999999998,
#   'upper': 1.2798202544766275,
#   'lower': 1.254168745523372},
#  Timestamp('2019-01-02 16:00:00'): {'center': 1.2662999999999998,
#   'upper': 1.2789194119472633,
#   'lower': 1.2536805880527362},
#  Timestamp('2019-01-02 17:00:00'): {'center': 1.2649865,
#   'upper': 1.2800063707332023,
#   'lower': 1.2499666292667977},
#  Timestamp('2019-01-02 18:00:00'): {'center': 1.263911,
#   'upper': 1.2795812116332734,
#   'lower': 1.2482407883667266},
#  Timestamp('2019-01-02 19:00:00'): {'center': 1.2629825000000001,
# ...

# %%
singles = rex.get_single_candlestick_patterns(gbp)
all_singles = []
for x in singles.keys():
    all_singles = all_singles + singles[x]

# %%
all_singles = set(all_singles)
all_singles = sorted(list(all_singles))
singles_series = pd.Series(dtype="float")
for x in range(len(gbp)):
    if gbp.iloc[x].name in all_singles:
        singles_series.loc[gbp.iloc[x].name] = 1
    else:
        singles_series.loc[gbp.iloc[x].name] = 0
gbp.insert(len(gbp.columns), "singles", singles_series)

# %%
gbp[gbp["singles"] == 1]
# Out:
#                         open     high      low    close  bodysize direction  \
# 2019-01-04 04:00:00  1.26690  1.26819  1.26683  1.26718   0.00028        up
# 2019-01-04 05:00:00  1.26717  1.26949  1.26657  1.26763   0.00046        up
# 2019-01-06 21:00:00  1.27418  1.27442  1.27392  1.27429   0.00011        up
# 2019-01-07 01:00:00  1.27486  1.27515  1.27419  1.27464   0.00022      down
# 2019-01-07 02:00:00  1.27464  1.27507  1.27397  1.27483   0.00019        up
# ...                      ...      ...      ...      ...       ...       ...
# 2020-12-29 21:00:00  1.35387  1.35447  1.35277  1.35440   0.00053        up
# 2020-12-30 00:00:00  1.35420  1.35569  1.35406  1.35442   0.00022        up
# 2020-12-30 08:00:00  1.35946  1.36066  1.35838  1.35998   0.00052        up
# 2020-12-30 11:00:00  1.36070  1.36087  1.35911  1.36026   0.00044      down
# 2020-12-31 01:00:00  1.36247  1.36365  1.36241  1.36272   0.00025        up
#
# ...

# %%
bb_df = pd.DataFrame.from_dict(bb, orient="index")

# %%
bb_df
# Out:
#                        center     upper     lower
# 2019-01-02 12:00:00  1.269102  1.281535  1.256669
# 2019-01-02 13:00:00  1.268388  1.281395  1.255381
# 2019-01-02 14:00:00  1.267681  1.280647  1.254716
# 2019-01-02 15:00:00  1.266994  1.279820  1.254169
# 2019-01-02 16:00:00  1.266300  1.278919  1.253681
# ...                       ...       ...       ...
# 2020-12-31 12:00:00  1.364429  1.368479  1.360378
# 2020-12-31 13:00:00  1.364658  1.368464  1.360851
# 2020-12-31 14:00:00  1.364849  1.368661  1.361037
# 2020-12-31 15:00:00  1.365009  1.368997  1.361020
# 2020-12-31 16:00:00  1.365108  1.369124  1.361092
#
# [12423 rows x 3 columns]

# %%
for col_name in bb_df.columns:
    bb_df.rename({col_name: "bb_"+col_name}, axis=1, inplace=True)

# %%
bb_df
# Out:
#                      bb_center  bb_upper  bb_lower
# 2019-01-02 12:00:00   1.269102  1.281535  1.256669
# 2019-01-02 13:00:00   1.268388  1.281395  1.255381
# 2019-01-02 14:00:00   1.267681  1.280647  1.254716
# 2019-01-02 15:00:00   1.266994  1.279820  1.254169
# 2019-01-02 16:00:00   1.266300  1.278919  1.253681
# ...                        ...       ...       ...
# 2020-12-31 12:00:00   1.364429  1.368479  1.360378
# 2020-12-31 13:00:00   1.364658  1.368464  1.360851
# 2020-12-31 14:00:00   1.364849  1.368661  1.361037
# 2020-12-31 15:00:00   1.365009  1.368997  1.361020
# 2020-12-31 16:00:00   1.365108  1.369124  1.361092
#
# [12423 rows x 3 columns]

# %%
gbp = pd.concat([gbp, bb_df], axis=1)

# %%
gbp
# Out:
#                         open     high      low    close  bodysize direction  \
# 2019-01-01 17:00:00  1.27459  1.27478  1.27227  1.27346   0.00113      down
# 2019-01-01 18:00:00  1.27346  1.27544  1.27317  1.27528   0.00182        up
# 2019-01-01 19:00:00  1.27528  1.27528  1.27448  1.27483   0.00045      down
# 2019-01-01 20:00:00  1.27482  1.27483  1.27412  1.27449   0.00033      down
# 2019-01-01 21:00:00  1.27449  1.27449  1.27229  1.27278   0.00171      down
# ...                      ...      ...      ...      ...       ...       ...
# 2020-12-31 12:00:00  1.36630  1.36783  1.36493  1.36501   0.00129      down
# 2020-12-31 13:00:00  1.36498  1.36619  1.36498  1.36584   0.00086        up
# 2020-12-31 14:00:00  1.36584  1.36748  1.36529  1.36669   0.00085        up
# 2020-12-31 15:00:00  1.36666  1.36755  1.36616  1.36755   0.00089        up
# 2020-12-31 16:00:00  1.36755  1.36787  1.36606  1.36632   0.00123      down
#
# ...

# %%
kelt = rex.get_keltner(gbp)

# %%
kelt_df = pd.DataFrame.from_dict(kelt, orient="index")
for col_name in kelt_df.columns:
    kelt_df.rename({col_name: "kelt_"+col_name}, axis=1, inplace=True)
gbp = pd.concat([gbp, kelt_df], axis=1)

# %%
gbp
# Out:
#                         open     high      low    close  bodysize direction  \
# 2019-01-01 17:00:00  1.27459  1.27478  1.27227  1.27346   0.00113      down
# 2019-01-01 18:00:00  1.27346  1.27544  1.27317  1.27528   0.00182        up
# 2019-01-01 19:00:00  1.27528  1.27528  1.27448  1.27483   0.00045      down
# 2019-01-01 20:00:00  1.27482  1.27483  1.27412  1.27449   0.00033      down
# 2019-01-01 21:00:00  1.27449  1.27449  1.27229  1.27278   0.00171      down
# ...                      ...      ...      ...      ...       ...       ...
# 2020-12-31 12:00:00  1.36630  1.36783  1.36493  1.36501   0.00129      down
# 2020-12-31 13:00:00  1.36498  1.36619  1.36498  1.36584   0.00086        up
# 2020-12-31 14:00:00  1.36584  1.36748  1.36529  1.36669   0.00085        up
# 2020-12-31 15:00:00  1.36666  1.36755  1.36616  1.36755   0.00089        up
# 2020-12-31 16:00:00  1.36755  1.36787  1.36606  1.36632   0.00123      down
#
# ...

# %%
mac = rex.get_macd(gbp)

# %%
mac
# Out:
# {Timestamp('2019-01-03 02:00:00'): {'macd': -0.005076923974489667,
#   'signal': -0.006328029727056878},
#  Timestamp('2019-01-03 03:00:00'): {'macd': -0.004636879479249512,
#   'signal': -0.005989799677495405},
#  Timestamp('2019-01-03 04:00:00'): {'macd': -0.004134771917688296,
#   'signal': -0.005618794125533983},
#  Timestamp('2019-01-03 05:00:00'): {'macd': -0.0037867985071466936,
#   'signal': -0.005252395001856525},
#  Timestamp('2019-01-03 06:00:00'): {'macd': -0.0035579669347034493,
#   'signal': -0.00491350938842591},
#  Timestamp('2019-01-03 07:00:00'): {'macd': -0.0033213841707129266,
#   'signal': -0.004595084344883314},
#  Timestamp('2019-01-03 08:00:00'): {'macd': -0.0028612536955554546,
#   'signal': -0.004248318215017742},
#  Timestamp('2019-01-03 09:00:00'): {'macd': -0.0025686585518218674,
#   'signal': -0.003912386282378567},
#  Timestamp('2019-01-03 10:00:00'): {'macd': -0.002121882771952688,
#   'signal': -0.0035542855802933914},
# ...

# %%
mac_df = pd.DataFrame.from_dict(mac, orient="index")
for col_name in mac_df.columns:
    mac_df.rename({col_name: "macd_"+col_name}, axis=1, inplace=True)
gbp = pd.concat([gbp, mac_df], axis=1)
gbp.tail()
# Out:
#                         open     high      low     close  bodysize direction  \
# 2020-12-31 12:00:00  1.36630  1.36783  1.36493  0.001915   0.00129      down
# 2020-12-31 13:00:00  1.36498  1.36619  1.36498  0.001817   0.00086        up
# 2020-12-31 14:00:00  1.36584  1.36748  1.36529  0.001786   0.00085        up
# 2020-12-31 15:00:00  1.36666  1.36755  1.36616  0.001811   0.00089        up
# 2020-12-31 16:00:00  1.36755  1.36787  1.36606  0.001712   0.00123      down
#
#                           pp  standard_r1  standard_s1    fib_r1  ...  \
# 2020-12-31 12:00:00  1.35969      1.36663      1.35446  1.364339  ...
# 2020-12-31 13:00:00  1.35969      1.36663      1.35446  1.364339  ...
# 2020-12-31 14:00:00  1.35969      1.36663      1.35446  1.364339  ...
# 2020-12-31 15:00:00  1.35969      1.36663      1.35446  1.364339  ...
# 2020-12-31 16:00:00  1.35969      1.36663      1.35446  1.364339  ...
#
#                         ema10  singles  bb_center  bb_upper  bb_lower  \
# ...

# %%
mac_df.drop
# Out:
# Index(['macd', 'signal'], dtype='object')

# %%
def add_dict_to_df(base_df, my_dict, prefix):
    """
    takes the dataframe to be added to, the dictionary to be added and prefix for column names and returns dataframe with added
    columns
    """
    my_df =  pd.DataFrame.from_dict(my_dict, orient="index")
    for col_name in my_df.columns:
        my_df.rename({col_name: prefix+col_name}, axis=1, inplace=True)
    return(pd.concat([base_df, my_df], axis=1))

# %%
gbp = add_dict_to_df(gbp, bb, "bb")

# %%
gbp.tail()
# Out:
#                         open     high      low    close  bodysize  volume  \
# 2020-12-31 12:00:00  1.36630  1.36783  1.36493  1.36501   0.00129       0
# 2020-12-31 13:00:00  1.36498  1.36619  1.36498  1.36584   0.00086       0
# 2020-12-31 14:00:00  1.36584  1.36748  1.36529  1.36669   0.00085       0
# 2020-12-31 15:00:00  1.36666  1.36755  1.36616  1.36755   0.00089       0
# 2020-12-31 16:00:00  1.36755  1.36787  1.36606  1.36632   0.00123       0
#
#                     direction    lomacd  losignal  locenter   loupper  \
# 2020-12-31 12:00:00      down  0.001915  0.002158  1.364255  1.369229
# 2020-12-31 13:00:00        up  0.001817  0.002090  1.364406  1.369252
# 2020-12-31 14:00:00        up  0.001786  0.002029  1.364623  1.369447
# 2020-12-31 15:00:00        up  0.001811  0.001986  1.364902  1.369623
# 2020-12-31 16:00:00      down  0.001712  0.001931  1.365037  1.369703
#
#                       lolower  bbcenter   bbupper   bblower
# ...

# %%
gbp.tail()
# Out:
#                         open     high      low     close  bodysize direction  \
# 2020-12-31 12:00:00  1.36630  1.36783  1.36493  0.001915   0.00129      down
# 2020-12-31 13:00:00  1.36498  1.36619  1.36498  0.001817   0.00086        up
# 2020-12-31 14:00:00  1.36584  1.36748  1.36529  0.001786   0.00085        up
# 2020-12-31 15:00:00  1.36666  1.36755  1.36616  0.001811   0.00089        up
# 2020-12-31 16:00:00  1.36755  1.36787  1.36606  0.001712   0.00123      down
#
#                           pp  standard_r1  standard_s1    fib_r1  ...  \
# 2020-12-31 12:00:00  1.35969      1.36663      1.35446  1.364339  ...
# 2020-12-31 13:00:00  1.35969      1.36663      1.35446  1.364339  ...
# 2020-12-31 14:00:00  1.35969      1.36663      1.35446  1.364339  ...
# 2020-12-31 15:00:00  1.35969      1.36663      1.35446  1.364339  ...
# 2020-12-31 16:00:00  1.35969      1.36663      1.35446  1.364339  ...
#
#                         ema10  singles  bb_center  bb_upper  bb_lower  \
# ...

# %%
rsi = rex.get_rsi(gbp)

# %%
rsi
# Out:
# {Timestamp('2019-01-02 06:00:00'): 26.446759259258755,
#  Timestamp('2019-01-02 07:00:00'): 24.464668094217856,
#  Timestamp('2019-01-02 08:00:00'): 19.34752547671721,
#  Timestamp('2019-01-02 09:00:00'): 19.075195135129306,
#  Timestamp('2019-01-02 10:00:00'): 18.38368446959265,
#  Timestamp('2019-01-02 11:00:00'): 18.171911569264736,
#  Timestamp('2019-01-02 12:00:00'): 17.00133829905333,
#  Timestamp('2019-01-02 13:00:00'): 19.759477189110257,
#  Timestamp('2019-01-02 14:00:00'): 28.876376093756008,
#  Timestamp('2019-01-02 15:00:00'): 28.76916238621868,
#  Timestamp('2019-01-02 16:00:00'): 27.859438704594467,
#  Timestamp('2019-01-02 17:00:00'): 14.075942945643078,
#  Timestamp('2019-01-02 18:00:00'): 26.736792131704405,
#  Timestamp('2019-01-02 19:00:00'): 34.12500900558723,
#  Timestamp('2019-01-02 20:00:00'): 34.06773610947603,
#  Timestamp('2019-01-02 21:00:00'): 33.92059441632803,
#  Timestamp('2019-01-02 22:00:00'): 34.780112218597324,
# ...

# %%
gbp = pd.concat([gbp, pd.Series(rsi).to_frame("rsi")], axis=1)

# %%
gbp.tail()
# Out:
#                         open     high      low    close  bodysize  volume  \
# 2020-12-31 12:00:00  1.36630  1.36783  1.36493  1.36501   0.00129       0
# 2020-12-31 13:00:00  1.36498  1.36619  1.36498  1.36584   0.00086       0
# 2020-12-31 14:00:00  1.36584  1.36748  1.36529  1.36669   0.00085       0
# 2020-12-31 15:00:00  1.36666  1.36755  1.36616  1.36755   0.00089       0
# 2020-12-31 16:00:00  1.36755  1.36787  1.36606  1.36632   0.00123       0
#
#                     direction    lomacd  losignal  locenter   loupper  \
# 2020-12-31 12:00:00      down  0.001915  0.002158  1.364255  1.369229
# 2020-12-31 13:00:00        up  0.001817  0.002090  1.364406  1.369252
# 2020-12-31 14:00:00        up  0.001786  0.002029  1.364623  1.369447
# 2020-12-31 15:00:00        up  0.001811  0.001986  1.364902  1.369623
# 2020-12-31 16:00:00      down  0.001712  0.001931  1.365037  1.369703
#
#                       lolower  bbcenter   bbupper   bblower        rsi
# ...

# %%
psar = rex.get_parabolic_sar(gbp)

# %%
psar
# Out:
# {Timestamp('2019-01-01 17:00:00'): {'direction': 'bear', 'psar': 1.27478},
#  Timestamp('2019-01-01 18:00:00'): {'direction': 'bear', 'psar': 1.36787},
#  Timestamp('2019-01-01 19:00:00'): {'direction': 'bear', 'psar': 1.365958},
#  Timestamp('2019-01-01 20:00:00'): {'direction': 'bear', 'psar': 1.36408424},
#  Timestamp('2019-01-01 21:00:00'): {'direction': 'bear', 'psar': 1.3622479552},
#  Timestamp('2019-01-01 22:00:00'): {'direction': 'bear',
#   'psar': 1.3604483960959999},
#  Timestamp('2019-01-01 23:00:00'): {'direction': 'bear',
#   'psar': 1.35868482817408},
#  Timestamp('2019-01-02 00:00:00'): {'direction': 'bear',
#   'psar': 1.3569565316105985},
#  Timestamp('2019-01-02 01:00:00'): {'direction': 'bear',
#   'psar': 1.3552628009783865},
#  Timestamp('2019-01-02 02:00:00'): {'direction': 'bear',
#   'psar': 1.3536029449588187},
#  Timestamp('2019-01-02 03:00:00'): {'direction': 'bear',
#   'psar': 1.3519762860596423},
# ...

# %%
gbp = add_dict_to_df(gbp, psar, "psar")

# %%
gbp.tail()
# Out:
#                         open     high      low    close  bodysize  volume  \
# 2020-12-31 12:00:00  1.36630  1.36783  1.36493  1.36501   0.00129       0
# 2020-12-31 13:00:00  1.36498  1.36619  1.36498  1.36584   0.00086       0
# 2020-12-31 14:00:00  1.36584  1.36748  1.36529  1.36669   0.00085       0
# 2020-12-31 15:00:00  1.36666  1.36755  1.36616  1.36755   0.00089       0
# 2020-12-31 16:00:00  1.36755  1.36787  1.36606  1.36632   0.00123       0
#
#                     direction    lomacd  losignal  locenter  ...   bbupper  \
# 2020-12-31 12:00:00      down  0.001915  0.002158  1.364255  ...  1.368479
# 2020-12-31 13:00:00        up  0.001817  0.002090  1.364406  ...  1.368464
# 2020-12-31 14:00:00        up  0.001786  0.002029  1.364623  ...  1.368661
# 2020-12-31 15:00:00        up  0.001811  0.001986  1.364902  ...  1.368997
# 2020-12-31 16:00:00      down  0.001712  0.001931  1.365037  ...  1.369124
#
# ...

# %%
stoch = rex.get_stochastic(gbp)

# %%
stoch
# Out:
# {Timestamp('2019-01-02 08:00:00'): {'stochastic': 3.701527614570547,
#   'signal': 4.387633842756867},
#  Timestamp('2019-01-02 09:00:00'): {'stochastic': 5.501985252410173,
#   'signal': 4.782568721313912},
#  Timestamp('2019-01-02 10:00:00'): {'stochastic': 2.31246474901309,
#   'signal': 3.83865920533127},
#  Timestamp('2019-01-02 11:00:00'): {'stochastic': 8.745445080686665,
#   'signal': 5.5199650273699765},
#  Timestamp('2019-01-02 12:00:00'): {'stochastic': 2.863092139509786,
#   'signal': 4.640333989736514},
#  Timestamp('2019-01-02 13:00:00'): {'stochastic': 5.726184279020727,
#   'signal': 5.778240499739059},
#  Timestamp('2019-01-02 14:00:00'): {'stochastic': 15.981259760540938,
#   'signal': 8.190178726357152},
#  Timestamp('2019-01-02 15:00:00'): {'stochastic': 16.53846153846131,
#   'signal': 12.748635192674323},
#  Timestamp('2019-01-02 16:00:00'): {'stochastic': 14.02337228714458,
#   'signal': 15.51436452871561},
# ...

# %%
gbp = add_dict_to_df(gbp, stoch, "stoch_")

# %%
gbp.tail()
# Out:
#                         open     high      low      close  bodysize  volume  \
# 2020-12-31 12:00:00  1.36630  1.36783  1.36493  51.621622   0.00129       0
# 2020-12-31 13:00:00  1.36498  1.36619  1.36498  61.805556   0.00086       0
# 2020-12-31 14:00:00  1.36584  1.36748  1.36529  69.255663   0.00085       0
# 2020-12-31 15:00:00  1.36666  1.36755  1.36616  82.781457   0.00089       0
# 2020-12-31 16:00:00  1.36755  1.36787  1.36606  60.314685   0.00123       0
#
#                     direction    lomacd  losignal  locenter  ...        rsi  \
# 2020-12-31 12:00:00      down  0.001915  0.002158  1.364255  ...  56.034580
# 2020-12-31 13:00:00        up  0.001817  0.002090  1.364406  ...  58.420398
# 2020-12-31 14:00:00        up  0.001786  0.002029  1.364623  ...  60.690911
# 2020-12-31 15:00:00        up  0.001811  0.001986  1.364902  ...  62.970950
# 2020-12-31 16:00:00      down  0.001712  0.001931  1.365037  ...  57.966821
#
# ...

# %%
williams = rex.get_williams_r(gbp)

# %%
williams
# Out:
# {Timestamp('2019-01-02 06:00:00'): 267.8317723999158,
#  Timestamp('2019-01-02 07:00:00'): 301.3954245487906,
#  Timestamp('2019-01-02 08:00:00'): 142.4346424542034,
#  Timestamp('2019-01-02 09:00:00'): 239.63104097618634,
#  Timestamp('2019-01-02 10:00:00'): 58.385490638076064,
#  Timestamp('2019-01-02 11:00:00'): 388.763929239286,
#  Timestamp('2019-01-02 12:00:00'): 82.55086618999428,
#  Timestamp('2019-01-02 13:00:00'): 231.59262254142317,
#  Timestamp('2019-01-02 14:00:00'): 765.4330952910451,
#  Timestamp('2019-01-02 15:00:00'): 838.5814032121601,
#  Timestamp('2019-01-02 16:00:00'): 709.3668495906905,
#  Timestamp('2019-01-02 17:00:00'): 420.3640968747174,
#  Timestamp('2019-01-02 18:00:00'): 1120.8381204893385,
#  Timestamp('2019-01-02 19:00:00'): 1920.1346292083267,
#  Timestamp('2019-01-02 20:00:00'): 2060.064127947984,
#  Timestamp('2019-01-02 21:00:00'): 2228.5321361058514,
#  Timestamp('2019-01-02 22:00:00'): 3028.484452922401,
# ...

# %%
gbp.max()["low"]
# Out:
# 1.36616

# %%
import importlib
importlib.reload(rex)
