# %%
import pandas as pd
import numpy as np
import rex
import targeter
from datetime import datetime
from sklearn.model_selection import cross_val_score, RandomizedSearchCV, train_test_split
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
from sqlalchemy import create_engine
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from imblearn.over_sampling import SMOTE

# %%
scale_cols = [
 'bodysize',
 'shadow',
 'wick',
 'macd_macd',
 'macd_signal',
 'rsi',
 'stoch_stochastic',
 'stoch_signal',
 'adx_adx',
 'williams',
 'bs3_mean',
 'w3_mean',
 's3_mean',
 'bs3_std',
 'w3_std',
 's3_std',
 'bs5_mean',
 'w5_mean',
 's5_mean',
 'bs5_std',
 'w5_std',
 's5_std',
 'stoch3_mean',
 'rsi3_mean',
 'macd3_mean',
 'adx3_mean',
 'stoch3_std',
 'rsi3_std',
 'macd3_std',
 'adx3_std',
 'stoch5_mean',
 'rsi5_mean',
 'macd5_mean',
 'adx5_mean',
 'stoch5_std',
 'rsi5_std',
 'macd5_std',
 'adx5_std',
 'bottom_bollinger',
 'top_bollinger',
 'mid_bollinger',
 'bollinger_range',
 'keltner_range',
 'bottom_keltner',
 'top_keltner',
 'above_sma10',
 'above_sma5',
 'above_ema5',
 'above_ema10',
 'ema5_sma10',
 'sma5_sma10',
 'stoch_over_signal',
 'macd_over_signal',
 'adx_over',
 "stoch_over_mean",
 "adx_over_mean",
 "rsi_over_mean",
 "macd_over_mean",
 "bs_over_mean",
 'bodysize-1',
 'shadow-1',
 'wick-1',
 'macd_macd-1',
 'macd_signal-1',
 'rsi-1',
 'stoch_stochastic-1',
 'stoch_signal-1',
 'adx_adx-1',
 'williams-1',
 'bottom_bollinger-1',
 'top_bollinger-1',
 'mid_bollinger-1',
 'bollinger_range-1',
 'keltner_range-1',
 'bottom_keltner-1',
 'top_keltner-1',
 'above_sma10-1',
 'above_sma5-1',
 'above_ema5-1',
 'above_ema10-1',
 'ema5_sma10-1',
 'sma5_sma10-1',
 'stoch_over_signal-1',
 'macd_over_signal-1',
 'adx_over-1',
 'bodysize-2',
 'shadow-2',
 'wick-2',
 'macd_macd-2',
 'macd_signal-2',
 'rsi-2',
 'stoch_stochastic-2',
 'stoch_signal-2',
 'adx_adx-2',
 'williams-2',
 'bottom_bollinger-2',
 'top_bollinger-2',
 'mid_bollinger-2',
 'bollinger_range-2',
 'keltner_range-2',
 'bottom_keltner-2',
 'top_keltner-2',
 'above_sma10-2',
 'above_sma5-2',
 'above_ema5-2',
 'above_ema10-2',
 'ema5_sma10-2',
 'sma5_sma10-2',
 'stoch_over_signal-2',
 'macd_over_signal-2',
 'adx_over-2',
]

non_scale_cols = [
 'singles',
 'bull_doubles',
 'bear_doubles',
 'morningstars',
 'whitesoldiers',
 'insideup',
 'eveningstars',
 'blackcrows',
 'insidedown',
 'direction_down',
 'direction_up',
 'psar_direction_bear',
 'psar_direction_bull',
 'bull_levels',
 'bear_levels',
 'bull_near_levels',
 'bear_near_levels',
 'singles-1',
 'bull_doubles-1',
 'bear_doubles-1',
 'morningstars-1',
 'whitesoldiers-1',
 'insideup-1',
 'eveningstars-1',
 'blackcrows-1',
 'insidedown-1',
 'direction_down-1',
 'direction_up-1',
 'psar_direction_bear-1',
 'psar_direction_bull-1',
 'bull_levels-1',
 'bear_levels-1',
 'bull_near_levels-1',
 'bear_near_levels-1',
 'singles-2',
 'bull_doubles-2',
 'bear_doubles-2',
 'morningstars-2',
 'whitesoldiers-2',
 'insideup-2',
 'eveningstars-2',
 'blackcrows-2',
 'insidedown-2',
 'direction_down-2',
 'direction_up-2',
 'psar_direction_bear-2',
 'psar_direction_bull-2',
 'bull_levels-2',
 'bear_levels-2',
 'bull_near_levels-2',
 'bear_near_levels-2']

# %%
def clean_turns(turns, df):
    new_turns = {}
    t_list = list(turns.keys())
    good_list = list(turns.keys())
    final_turns = {}
    for x in t_list[1:]:
        prev_x = t_list[t_list.index(x)-1]
        if(turns[x] == turns[prev_x]):
            if turns[x] == "up":
                if df.loc[x, ['open', 'close']].min() >= df.loc[prev_x, ['open' ,'close']].min():
                    discard_x = x
                else:
                    discard_x = prev_x
            else:
                
                if df.loc[x, ['open', 'close']].max() <= df.loc[prev_x, ['open' ,'close']].max():
                    discard_x = x
                else:
                    discard_x = prev_x
            try:
                good_list.remove(discard_x)
            except(ValueError):
                print("Already removed")
            
    for new_x in good_list:
        new_turns[new_x] = turns[new_x]
        
    new_turns_keys = list(new_turns.keys())
    for peak_x in new_turns_keys[:-1]:
        start_index = df.index.get_loc(peak_x)-1
        stop_index = df.index.get_loc(new_turns_keys[new_turns_keys.index(peak_x)+1])
        
        temp_df = df[start_index:stop_index]
               
        if new_turns[peak_x] == "up":
            peak_up_time = peak_x
            for index, row in temp_df.iterrows():
                if row[["open", "close"]].min() <= df.loc[peak_up_time, ["open", "close"]].min():
                    peak_up_time = index
            if df.loc[peak_up_time, 'direction_down'] == 0 and df.iloc[df.index.get_loc(peak_up_time)-1]["direction_down"] == 1:
                peak_up_time = df.iloc[df.index.get_loc(peak_up_time)-1].name
            final_turns[peak_up_time] = "up"
                                
            
        if new_turns[peak_x] == "down":
            peak_down_time = peak_x
            for index, row in temp_df.iterrows():
                if row[["open", "close"]].max() >= df.loc[peak_down_time, ["open", "close"]].max():
                    peak_down_time = index
            if df.loc[peak_down_time, 'direction_up'] == 0 and df.iloc[df.index.get_loc(peak_down_time)-1]["direction_up"] == 1:
                peak_down_time = df.iloc[df.index.get_loc(peak_down_time)-1].name
            final_turns[peak_down_time] = "down"
        
    
    
    return(final_turns)

# %%
def new_means(in_df):
    hdf = in_df
    
    ndf = targeter.reproduce_columns(hdf, 5)
    
    s3 = []
    w3 = []
    b3 = []
    stoch_3 = []
    macd_3 = []
    rsi_3 = []
    adx_3 = []
    for x in range(1,4):
        s3.append(f"shadow-{str(x)}")
        b3.append(f"bodysize-{str(x)}")
        w3.append(f"wick-{str(x)}")
        stoch_3.append(f"stoch_stochastic-{str(x)}")
        macd_3.append(f"macd_macd-{str(x)}")
        rsi_3.append(f"rsi-{str(x)}")
        adx_3.append(f"adx_adx-{str(x)}")
    
    s5 = []
    w5 = []
    b5 = []
    stoch_5 = []
    macd_5 = []
    rsi_5 = []
    adx_5 = []
    for x in range(1,6):
        s5.append(f"shadow-{str(x)}")
        b5.append(f"bodysize-{str(x)}")
        w5.append(f"wick-{str(x)}")
        stoch_5.append(f"stoch_stochastic-{str(x)}")
        macd_5.append(f"macd_macd-{str(x)}")
        rsi_5.append(f"rsi-{str(x)}")
        adx_5.append(f"adx_adx-{str(x)}")
        
        
    ndf["bs3_mean"] = ndf[b3].mean(axis=1)
    ndf["w3_mean"] = ndf[w3].mean(axis=1)
    ndf["s3_mean"] = ndf[s3].mean(axis=1)

    ndf["bs3_std"] = ndf[b3].std(axis=1)
    ndf["w3_std"] = ndf[w3].std(axis=1)
    ndf["s3_std"] = ndf[s3].std(axis=1)
    
    ndf["bs5_mean"] = ndf[b5].mean(axis=1)
    ndf["w5_mean"] = ndf[w5].mean(axis=1)
    ndf["s5_mean"] = ndf[s5].mean(axis=1)

    ndf["bs5_std"] = ndf[b5].std(axis=1)
    ndf["w5_std"] = ndf[w5].std(axis=1)
    ndf["s5_std"] = ndf[s5].std(axis=1)
    
    ndf["stoch3_mean"] = ndf[stoch_3].mean(axis=1)
    ndf["rsi3_mean"] = ndf[rsi_3].mean(axis=1)
    ndf["macd3_mean"] = ndf[macd_3].mean(axis=1)
    ndf["adx3_mean"] = ndf[adx_3].mean(axis=1)

    ndf["stoch3_std"] = ndf[stoch_3].std(axis=1)
    ndf["rsi3_std"] = ndf[rsi_3].std(axis=1)
    ndf["macd3_std"] = ndf[macd_3].std(axis=1)
    ndf["adx3_std"] = ndf[adx_3].std(axis=1)
    
    ndf["stoch5_mean"] = ndf[stoch_5].mean(axis=1)
    ndf["rsi5_mean"] = ndf[rsi_5].mean(axis=1)
    ndf["macd5_mean"] = ndf[macd_5].mean(axis=1)
    ndf["adx5_mean"] = ndf[adx_5].mean(axis=1)

    ndf["stoch5_std"] = ndf[stoch_5].std(axis=1)
    ndf["rsi5_std"] = ndf[rsi_5].std(axis=1)
    ndf["macd5_std"] = ndf[macd_5].std(axis=1)
    ndf["adx5_std"] = ndf[adx_5].std(axis=1)
    
    
    

    dropable = ["bs3", "bs6", "w3", "w6", "s3", "s6"]
    
    for x in range(1, 6):
        for col in hdf.columns:
            dropable.append(f"{col}-{str(x)}")
    
    return(ndf.drop(dropable, axis=1))

# %%
def shape_df(in_df):
    mean_bs = df["bodysize"].abs().mean()
    threshold = mean_bs/5
    df["bottom_bollinger"] = df["bb_lower"] - df["close"]
    df["top_bollinger"] = df["close"] - df["bb_upper"]
    df["mid_bollinger"] = df["close"] - df["bb_center"]
    df["bollinger_range"] = df["bb_upper"] - df["bb_center"]
    df["keltner_range"] = df["kelt_upper"] - df["kelt_center"]
    df["bottom_keltner"] = df["kelt_lower"] - df["close"]
    df["top_keltner"] = df["close"] - df["kelt_upper"]
    df["above_sma10"] = df["close"] - df["sma10"]
    df["above_sma5"] = df["close"] - df["sma10"]
    df["above_ema5"] = df["close"] - df["ema5"]
    df["above_ema10"] = df["close"] - df["ema10"]
    df["ema5_sma10"] = df["ema5"] - df["sma10"]
    df["sma5_sma10"] = df["sma5"] - df["sma10"]
    df["stoch_over_signal"] = df["stoch_stochastic"] - df["stoch_signal"]
    df["macd_over_signal"] = df["macd_macd"] - df["macd_signal"]
    df["adx_over"] = df["adx_pdmi"] - df["adx_ndmi"]
    df["stoch_over_mean"] = df["stoch_stochastic"] - df["stoch3_mean"]
    df["adx_over_mean"] = df["adx_adx"] - df["adx3_mean"]
    df["rsi_over_mean"] = df["rsi"] - df["rsi3_mean"]
    df["macd_over_mean"] = df["macd_macd"] - df["macd3_mean"]
    df["bs_over_mean"] = df["close"] - df["bs3_mean"]
    
    
    levels = [
        "level_1",
        "level_2",
        "level_3",
        "level_4",
        "level_5",
        "pp",
        "standard_r1",
        "standard_s1",
        "fib_r1",
        "fib_s1"
    ]
    
    bull_conditions = []
    bear_conditions = []
    bear_near_conditions = []
    bull_near_conditions = []
    
    for level in levels:
        bull_conditions.append(
            (df['close'] > df[level]) & (df['open'] < df[level])
        )
        bear_conditions.append(
            (df['close'] < df[level]) & (df['open'] > df[level])
        )
        bear_near_conditions.append(
            (df['open'] < df[level]) & (df['close'] < df[level]) & (df[level]-df['close'] < threshold)
        )
        bull_near_conditions.append(
            (df['open'] > df[level]) & (df['close'] > df[level]) & (df['close']-df[level] < threshold)
        )
        
    df["bull_levels"] = np.select(bull_conditions, np.ones(len(levels)), default=0)
    df["bear_levels"] = np.select(bear_conditions, np.ones(len(levels)), default=0)
    df["bull_near_levels"] = np.select(bull_near_conditions, np.ones(len(levels)), default=0)
    df["bear_near_levels"] = np.select(bear_near_conditions, np.ones(len(levels)), default=0)
    
    drop_cols = [
        "bb_center",
        "bb_upper",
        "bb_lower",
        "kelt_center",
        "kelt_upper",
        "kelt_lower",
        "ema5",
        "sma5",
        "sma10",
        "ema10",
        "psar_psar",
        "curr_trend_down",
        "curr_trend_up",
        "level_1",
        "level_2",
        "level_3",
        "level_4",
        "level_5",
        "pp",
        "standard_r1",
        "standard_s1",
        "fib_r1",
        "fib_s1",
        "adx_pdmi",
        "adx_ndmi",
        "open",
        "high",
        "low",
        "close"
    ]
    
    
    return(df.drop(drop_cols, axis=1))

# %%
def double_up(in_df, fac=2):
    drops = ['bs3_mean', 'w3_mean', 's3_mean', 'bs3_std', 'w3_std', 's3_std',
       'bs5_mean', 'w5_mean', 's5_mean', 'bs5_std', 'w5_std', 's5_std',
       'stoch3_mean', 'rsi3_mean', 'macd3_mean', 'adx3_mean', 'stoch3_std',
       'rsi3_std', 'macd3_std', 'adx3_std', 'stoch5_mean', 'rsi5_mean',
       'macd5_mean', 'adx5_mean', 'stoch5_std', 'rsi5_std', 'macd5_std',
       'adx5_std', 'target_up', 'target_down']
    
    df = in_df.copy(deep=True)
    df = targeter.reproduce_columns(df, col_count=fac)
    
    dropable = []
    for i in range(1, fac+1):
        for col in drops:
            dropable.append(f"{col}-{str(i)}")
            
    return(df.drop(dropable, axis=1))

# %%
def getfirst_pandas(condition, df):
    cond = df[condition(df)]
    if not cond.empty:
        return(cond.iloc[0].name)
    else:
        return None

# %%
def turn_target(in_df, turns, fac=30):
    df = in_df.copy(deep=True)
    mean_bs = df["bodysize"].abs().mean()
    df["target_up"] = np.zeros(len(df))
    df["target_down"] = np.zeros(len(df))

    turns_keys = list(turns.keys())
    for t_time in  turns_keys:
        if df.index.get_loc(t_time) < len(df)+fac+2:
            try:
                turn0 = df.index.get_loc(t_time)
                turn2 = df.iloc[turn0 + 2].name
                start_point = df.index.get_loc(turn2)
                end_point = start_point + fac
                small_df = df[start_point:end_point]
                small_keys = sorted(list(small_df.index))
                sl = df.loc[t_time, 'close']
                goal_point_up = df.loc[turn2, "close"] + (mean_bs*4)
                goal_point_down = df.loc[turn2, "close"] - (mean_bs*4)

        
                if turns[t_time] == "up":
                    goal_reached_up = getfirst_pandas(lambda x: x.high >= goal_point_up, small_df)
                    if goal_reached_up:
                        goal_index = small_keys.index(goal_reached_up)
                        if small_df[:goal_index]["low"].min() > sl:
                            df.loc[turn2, "target_up"] = 1
            
                if turns[t_time] == "down":
                    goal_reached_down = getfirst_pandas(lambda x: x.high <= goal_point_down, small_df)
                    if goal_reached_down:
                        goal_index = small_keys.index(goal_reached_down)
                        if small_df[:goal_index]["high"].max() < sl:
                            df.loc[turn2, "target_down"] = 1
            except(IndexError):
                print("Fail")
            
    return(df)

# %%
def overall_trend(in_df, daily_df, fac=4):
    df = in_df.copy(deep=True)
    trend_df = targeter.reproduce_columns(daily_df, fac)
    summables= ['bodysize']
    for x in range(1, fac+1):
        summables.append(f"bodysize-{str(x)}")
    trend_df["mean_trend"] = trend_df[summables].mean(axis=1)
    
    trend_df_keys = list(trend_df.index)
    
    for index, row in df.iterrows():
        small_list = [item for item in trend_df_keys if item < index.replace(hour=0)]
        df.loc[index, 'overall_trend'] = trend_df.loc[max(small_list), "mean_trend"]

    return(df)

# %%
engine = create_engine("mysql+pymysql://rex:#Pass123@localhost/new_ml")
sql_h = "SELECT * FROM `gbpusd_1h` ORDER BY `index` ASC"
sql_d = "SELECT * FROM `gbpusd_d` ORDER BY `index` ASC"
new_df = pd.read_sql(sql_h, engine, index_col="index")
df_d = pd.read_sql(sql_d, engine, index_col="index")

# %%
df = overall_trend(new_df, df_d)
turns = rex.get_turns(df)
turns = clean_turns(turns, df)
df = turn_target(df, turns)

# %%
turns = rex.get_turns(new_df)
turns = clean_turns(turns, new_df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9564/1230994337.py in <module>
#       1 turns = rex.get_turns(new_df)
# ----> 2 turns = clean_turns(turns, new_df)
#
# ~\AppData\Local\Temp/ipykernel_9564/4156245521.py in clean_turns(turns, df)
#      18                 else:
#      19                     discard_x = prev_x
# ---> 20             good_list.remove(discard_x)
#      21
#      22     for new_x in good_list:
#
# ValueError: list.remove(x): x not in list

# %%
# df = overall_trend(new_df, df_d)
# df = targeter.get_target_up_down(df)
df = new_means(df)
df = shape_df(df)
df = double_up(df)

# %% [markdown]
# ## Trying with old targeting method and no scaling

# %%
from pprint import pprint
pprint(list(df.columns))
# Out:
# ['bodysize',
#  'shadow',
#  'wick',
#  'singles',
#  'bull_doubles',
#  'bear_doubles',
#  'morningstars',
#  'whitesoldiers',
#  'insideup',
#  'eveningstars',
#  'blackcrows',
#  'insidedown',
#  'macd_macd',
#  'macd_signal',
#  'rsi',
#  'stoch_stochastic',
#  'stoch_signal',
#  'adx_adx',
#  'williams',
#  'direction_down',
#  'direction_up',
#  'psar_direction_bear',
#  'psar_direction_bull',
#  'overall_trend',
#  'target_up',
#  'target_down',
#  'bs3_mean',
#  'w3_mean',
#  's3_mean',
#  'bs3_std',
#  'w3_std',
#  's3_std',
#  'bs5_mean',
#  'w5_mean',
#  's5_mean',
#  'bs5_std',
#  'w5_std',
#  's5_std',
#  'stoch3_mean',
#  'rsi3_mean',
#  'macd3_mean',
#  'adx3_mean',
#  'stoch3_std',
#  'rsi3_std',
#  'macd3_std',
#  'adx3_std',
#  'stoch5_mean',
#  'rsi5_mean',
#  'macd5_mean',
#  'adx5_mean',
#  'stoch5_std',
#  'rsi5_std',
#  'macd5_std',
#  'adx5_std',
#  'bottom_bollinger',
#  'top_bollinger',
#  'mid_bollinger',
#  'bollinger_range',
#  'keltner_range',
#  'bottom_keltner',
#  'top_keltner',
#  'above_sma10',
#  'above_sma5',
#  'above_ema5',
#  'above_ema10',
#  'ema5_sma10',
#  'sma5_sma10',
#  'stoch_over_signal',
#  'macd_over_signal',
#  'adx_over',
#  'stoch_over_mean',
#  'adx_over_mean',
#  'rsi_over_mean',
#  'macd_over_mean',
#  'bs_over_mean',
#  'bull_levels',
#  'bear_levels',
#  'bull_near_levels',
#  'bear_near_levels',
#  'bodysize-1',
#  'shadow-1',
#  'wick-1',
#  'singles-1',
#  'bull_doubles-1',
#  'bear_doubles-1',
#  'morningstars-1',
#  'whitesoldiers-1',
#  'insideup-1',
#  'eveningstars-1',
#  'blackcrows-1',
#  'insidedown-1',
#  'macd_macd-1',
#  'macd_signal-1',
#  'rsi-1',
#  'stoch_stochastic-1',
#  'stoch_signal-1',
#  'adx_adx-1',
#  'williams-1',
#  'direction_down-1',
#  'direction_up-1',
#  'psar_direction_bear-1',
#  'psar_direction_bull-1',
#  'overall_trend-1',
#  'bottom_bollinger-1',
#  'top_bollinger-1',
#  'mid_bollinger-1',
#  'bollinger_range-1',
#  'keltner_range-1',
#  'bottom_keltner-1',
#  'top_keltner-1',
#  'above_sma10-1',
#  'above_sma5-1',
#  'above_ema5-1',
#  'above_ema10-1',
#  'ema5_sma10-1',
#  'sma5_sma10-1',
#  'stoch_over_signal-1',
#  'macd_over_signal-1',
#  'adx_over-1',
#  'stoch_over_mean-1',
#  'adx_over_mean-1',
#  'rsi_over_mean-1',
#  'macd_over_mean-1',
#  'bs_over_mean-1',
#  'bull_levels-1',
#  'bear_levels-1',
#  'bull_near_levels-1',
#  'bear_near_levels-1',
#  'bodysize-2',
#  'shadow-2',
#  'wick-2',
#  'singles-2',
#  'bull_doubles-2',
#  'bear_doubles-2',
#  'morningstars-2',
#  'whitesoldiers-2',
#  'insideup-2',
#  'eveningstars-2',
#  'blackcrows-2',
#  'insidedown-2',
#  'macd_macd-2',
#  'macd_signal-2',
#  'rsi-2',
#  'stoch_stochastic-2',
#  'stoch_signal-2',
#  'adx_adx-2',
#  'williams-2',
#  'direction_down-2',
#  'direction_up-2',
#  'psar_direction_bear-2',
#  'psar_direction_bull-2',
#  'overall_trend-2',
#  'bottom_bollinger-2',
#  'top_bollinger-2',
#  'mid_bollinger-2',
#  'bollinger_range-2',
#  'keltner_range-2',
#  'bottom_keltner-2',
#  'top_keltner-2',
#  'above_sma10-2',
#  'above_sma5-2',
#  'above_ema5-2',
#  'above_ema10-2',
#  'ema5_sma10-2',
#  'sma5_sma10-2',
#  'stoch_over_signal-2',
#  'macd_over_signal-2',
#  'adx_over-2',
#  'stoch_over_mean-2',
#  'adx_over_mean-2',
#  'rsi_over_mean-2',
#  'macd_over_mean-2',
#  'bs_over_mean-2',
#  'bull_levels-2',
#  'bear_levels-2',
#  'bull_near_levels-2',
#  'bear_near_levels-2']

# %%
X = df[:-720].drop(["target_up", "target_down"], axis=1)
y = df[:-720]["target_up"]

# %%
drop_columns = [
]
Xd = X.drop(drop_columns, axis=1)
X_train, X_test, y_train, y_test = train_test_split(Xd, y)

# %%
over = SMOTE()
from sklearn.svm import LinearSVC

# %%
X_t, y_t = over.fit_resample(X_train, y_train)

# %%
clf = RandomForestClassifier(min_impurity_decrease = 0.0001,
                             class_weight={0:1,1:5},
                             random_state=42).fit(X_t, y_t)

# %%
clf.score(X_test, y_test)
# Out:
# 0.9344687152906331

# %%
preds = clf.predict(X_test)

# %%
cm = confusion_matrix(y_test, preds)
print(cm)
# Out:
# [[12453   874]
#  [   11   167]]

# %%
new_X = df[-720:].drop(drop_columns+["target_up", "target_down"], axis=1)
new_y = df[-720:]["target_up"]

new_preds = clf.predict(new_X)
new_cm = confusion_matrix(new_y, new_preds)
print(new_cm)
# Out:
# [[658  51]
#  [  3   8]]

# %%
Counter(y_test)
# Out:
# Counter({0.0: 10783, 1.0: 2715})

# %%
for x in range(len(new_y)):
    if new_y.values[x] == 1 and new_preds[x] == 1:
        print(new_X.iloc[x].name)
# Out:
# 2021-09-22 17:00:00
# 2021-09-30 15:00:00
# 2021-10-08 12:00:00
# 2021-10-13 04:00:00
# 2021-10-15 04:00:00
# 2021-10-20 16:00:00
# 2021-10-25 17:00:00
# 2021-10-28 05:00:00

# %%
new_y[new_y==1]
# Out:
# index
# 2021-09-22 17:00:00    1.0
# 2021-09-30 15:00:00    1.0
# 2021-10-08 12:00:00    1.0
# 2021-10-11 02:00:00    1.0
# 2021-10-13 04:00:00    1.0
# 2021-10-15 04:00:00    1.0
# 2021-10-19 01:00:00    1.0
# 2021-10-20 16:00:00    1.0
# 2021-10-25 17:00:00    1.0
# 2021-10-26 10:00:00    1.0
# 2021-10-28 05:00:00    1.0
# Name: target_up, dtype: float64

# %%
pprint(turns)
# Out:
# {Timestamp('2013-01-04 13:00:00'): 'up',
#  Timestamp('2013-01-07 00:00:00'): 'down',
#  Timestamp('2013-01-07 06:00:00'): 'up',
#  Timestamp('2013-01-07 23:00:00'): 'down',
#  Timestamp('2013-01-08 16:00:00'): 'up',
#  Timestamp('2013-01-09 00:00:00'): 'down',
#  Timestamp('2013-01-09 04:00:00'): 'up',
#  Timestamp('2013-01-09 10:00:00'): 'down',
#  Timestamp('2013-01-09 16:00:00'): 'up',
#  Timestamp('2013-01-09 21:00:00'): 'down',
#  Timestamp('2013-01-10 02:00:00'): 'up',
#  Timestamp('2013-01-10 22:00:00'): 'down',
#  Timestamp('2013-01-11 15:00:00'): 'up',
#  Timestamp('2013-01-11 18:00:00'): 'down',
#  Timestamp('2013-01-11 21:00:00'): 'up',
#  Timestamp('2013-01-14 04:00:00'): 'down',
#  Timestamp('2013-01-14 14:00:00'): 'up',
#  Timestamp('2013-01-15 09:00:00'): 'down',
#  Timestamp('2013-01-15 13:00:00'): 'up',
#  Timestamp('2013-01-15 17:00:00'): 'down',
#  Timestamp('2013-01-15 23:00:00'): 'up',
#  Timestamp('2013-01-16 02:00:00'): 'down',
#  Timestamp('2013-01-16 15:00:00'): 'up',
#  Timestamp('2013-01-17 02:00:00'): 'down',
#  Timestamp('2013-01-17 08:00:00'): 'up',
#  Timestamp('2013-01-17 12:00:00'): 'down',
#  Timestamp('2013-01-17 15:00:00'): 'up',
#  Timestamp('2013-01-17 20:00:00'): 'down',
#  Timestamp('2013-01-18 22:00:00'): 'up',
#  Timestamp('2013-01-21 10:00:00'): 'down',
#  Timestamp('2013-01-21 20:00:00'): 'up',
#  Timestamp('2013-01-22 06:00:00'): 'down',
#  Timestamp('2013-01-22 10:00:00'): 'up',
#  Timestamp('2013-01-22 13:00:00'): 'down',
#  Timestamp('2013-01-23 08:00:00'): 'up',
#  Timestamp('2013-01-23 14:00:00'): 'down',
#  Timestamp('2013-01-24 02:00:00'): 'up',
#  Timestamp('2013-01-24 09:00:00'): 'down',
#  Timestamp('2013-01-24 18:00:00'): 'up',
#  Timestamp('2013-01-24 20:00:00'): 'down',
#  Timestamp('2013-01-25 12:00:00'): 'up',
#  Timestamp('2013-01-25 15:00:00'): 'down',
#  Timestamp('2013-01-28 19:00:00'): 'up',
#  Timestamp('2013-01-29 22:00:00'): 'down',
#  Timestamp('2013-01-30 09:00:00'): 'up',
#  Timestamp('2013-01-31 10:00:00'): 'down',
#  Timestamp('2013-01-31 12:00:00'): 'up',
#  Timestamp('2013-02-01 08:00:00'): 'down',
#  Timestamp('2013-02-04 04:00:00'): 'up',
#  Timestamp('2013-02-04 19:00:00'): 'down',
#  Timestamp('2013-02-05 08:00:00'): 'up',
#  Timestamp('2013-02-05 10:00:00'): 'down',
#  Timestamp('2013-02-05 18:00:00'): 'up',
#  Timestamp('2013-02-06 00:00:00'): 'down',
#  Timestamp('2013-02-06 09:00:00'): 'up',
#  Timestamp('2013-02-06 11:00:00'): 'down',
#  Timestamp('2013-02-06 18:00:00'): 'up',
#  Timestamp('2013-02-06 20:00:00'): 'down',
#  Timestamp('2013-02-07 04:00:00'): 'up',
#  Timestamp('2013-02-07 13:00:00'): 'down',
#  Timestamp('2013-02-07 18:00:00'): 'up',
#  Timestamp('2013-02-08 16:00:00'): 'down',
#  Timestamp('2013-02-11 00:00:00'): 'up',
#  Timestamp('2013-02-11 02:00:00'): 'down',
#  Timestamp('2013-02-12 14:00:00'): 'up',
#  Timestamp('2013-02-13 05:00:00'): 'down',
#  Timestamp('2013-02-14 19:00:00'): 'up',
#  Timestamp('2013-02-15 09:00:00'): 'down',
#  Timestamp('2013-02-15 10:00:00'): 'up',
#  Timestamp('2013-02-15 18:00:00'): 'down',
#  Timestamp('2013-02-18 09:00:00'): 'up',
#  Timestamp('2013-02-18 13:00:00'): 'down',
#  Timestamp('2013-02-18 19:00:00'): 'up',
#  Timestamp('2013-02-19 09:00:00'): 'down',
#  Timestamp('2013-02-19 23:00:00'): 'up',
#  Timestamp('2013-02-20 03:00:00'): 'down',
#  Timestamp('2013-02-21 06:00:00'): 'up',
#  Timestamp('2013-02-21 17:00:00'): 'down',
#  Timestamp('2013-02-21 20:00:00'): 'up',
#  Timestamp('2013-02-22 13:00:00'): 'down',
#  Timestamp('2013-02-25 03:00:00'): 'up',
#  Timestamp('2013-02-25 09:00:00'): 'down',
#  Timestamp('2013-02-25 14:00:00'): 'up',
#  Timestamp('2013-02-26 04:00:00'): 'down',
#  Timestamp('2013-02-27 06:00:00'): 'up',
#  Timestamp('2013-02-27 15:00:00'): 'down',
#  Timestamp('2013-02-27 19:00:00'): 'up',
#  Timestamp('2013-02-28 13:00:00'): 'down',
#  Timestamp('2013-02-28 22:00:00'): 'up',
#  Timestamp('2013-03-01 06:00:00'): 'down',
#  Timestamp('2013-03-01 16:00:00'): 'up',
#  Timestamp('2013-03-04 04:00:00'): 'down',
#  Timestamp('2013-03-04 10:00:00'): 'up',
#  Timestamp('2013-03-05 10:00:00'): 'down',
#  Timestamp('2013-03-05 17:00:00'): 'up',
#  Timestamp('2013-03-06 02:00:00'): 'down',
#  Timestamp('2013-03-07 01:00:00'): 'up',
#  Timestamp('2013-03-07 06:00:00'): 'down',
#  Timestamp('2013-03-07 08:00:00'): 'up',
#  Timestamp('2013-03-07 14:00:00'): 'down',
#  Timestamp('2013-03-08 06:00:00'): 'up',
#  Timestamp('2013-03-08 12:00:00'): 'down',
#  Timestamp('2013-03-11 00:00:00'): 'up',
#  Timestamp('2013-03-11 08:00:00'): 'down',
#  Timestamp('2013-03-11 12:00:00'): 'up',
#  Timestamp('2013-03-11 19:00:00'): 'down',
#  Timestamp('2013-03-12 10:00:00'): 'up',
#  Timestamp('2013-03-13 12:00:00'): 'down',
#  Timestamp('2013-03-13 22:00:00'): 'up',
#  Timestamp('2013-03-14 02:00:00'): 'down',
#  Timestamp('2013-03-14 13:00:00'): 'up',
#  Timestamp('2013-03-15 13:00:00'): 'down',
#  Timestamp('2013-03-18 01:00:00'): 'up',
#  Timestamp('2013-03-18 10:00:00'): 'down',
#  Timestamp('2013-03-18 23:00:00'): 'up',
#  Timestamp('2013-03-19 02:00:00'): 'down',
#  Timestamp('2013-03-19 09:00:00'): 'up',
#  Timestamp('2013-03-19 13:00:00'): 'down',
#  Timestamp('2013-03-20 09:00:00'): 'up',
#  Timestamp('2013-03-20 15:00:00'): 'down',
#  Timestamp('2013-03-20 23:00:00'): 'up',
#  Timestamp('2013-03-25 01:00:00'): 'down',
#  Timestamp('2013-03-25 22:00:00'): 'up',
#  Timestamp('2013-03-26 09:00:00'): 'down',
#  Timestamp('2013-03-26 18:00:00'): 'up',
#  Timestamp('2013-03-27 09:00:00'): 'down',
#  Timestamp('2013-03-27 12:00:00'): 'up',
#  Timestamp('2013-03-29 03:00:00'): 'down',
#  Timestamp('2013-03-29 07:00:00'): 'up',
#  Timestamp('2013-04-01 00:00:00'): 'down',
#  Timestamp('2013-04-01 05:00:00'): 'up',
#  Timestamp('2013-04-01 19:00:00'): 'down',
#  Timestamp('2013-04-02 01:00:00'): 'up',
#  Timestamp('2013-04-02 05:00:00'): 'down',
#  Timestamp('2013-04-03 04:00:00'): 'up',
#  Timestamp('2013-04-03 19:00:00'): 'down',
#  Timestamp('2013-04-04 09:00:00'): 'up',
#  Timestamp('2013-04-05 02:00:00'): 'down',
#  Timestamp('2013-04-05 09:00:00'): 'up',
#  Timestamp('2013-04-08 01:00:00'): 'down',
#  Timestamp('2013-04-08 21:00:00'): 'up',
#  Timestamp('2013-04-09 20:00:00'): 'down',
#  Timestamp('2013-04-10 02:00:00'): 'up',
#  Timestamp('2013-04-10 04:00:00'): 'down',
#  Timestamp('2013-04-10 14:00:00'): 'up',
#  Timestamp('2013-04-11 17:00:00'): 'down',
#  Timestamp('2013-04-12 00:00:00'): 'up',
#  Timestamp('2013-04-12 04:00:00'): 'down',
#  Timestamp('2013-04-15 10:00:00'): 'up',
#  Timestamp('2013-04-15 12:00:00'): 'down',
#  Timestamp('2013-04-16 03:00:00'): 'up',
#  Timestamp('2013-04-16 19:00:00'): 'down',
#  Timestamp('2013-04-18 10:00:00'): 'up',
#  Timestamp('2013-04-18 18:00:00'): 'down',
#  Timestamp('2013-04-19 02:00:00'): 'up',
#  Timestamp('2013-04-19 10:00:00'): 'down',
#  Timestamp('2013-04-22 02:00:00'): 'up',
#  Timestamp('2013-04-23 01:00:00'): 'down',
#  Timestamp('2013-04-23 10:00:00'): 'up',
#  Timestamp('2013-04-23 16:00:00'): 'down',
#  Timestamp('2013-04-24 01:00:00'): 'up',
#  Timestamp('2013-04-24 11:00:00'): 'down',
#  Timestamp('2013-04-24 17:00:00'): 'up',
#  Timestamp('2013-04-25 14:00:00'): 'down',
#  Timestamp('2013-04-25 21:00:00'): 'up',
#  Timestamp('2013-04-26 04:00:00'): 'down',
#  Timestamp('2013-04-26 10:00:00'): 'up',
#  Timestamp('2013-04-29 11:00:00'): 'down',
#  Timestamp('2013-04-30 03:00:00'): 'up',
#  Timestamp('2013-04-30 18:00:00'): 'down',
#  Timestamp('2013-04-30 20:00:00'): 'up',
#  Timestamp('2013-05-01 20:00:00'): 'down',
#  Timestamp('2013-05-02 08:00:00'): 'up',
#  Timestamp('2013-05-02 13:00:00'): 'down',
#  Timestamp('2013-05-02 16:00:00'): 'up',
#  Timestamp('2013-05-03 02:00:00'): 'down',
#  Timestamp('2013-05-03 14:00:00'): 'up',
#  Timestamp('2013-05-06 02:00:00'): 'down',
#  Timestamp('2013-05-06 16:00:00'): 'up',
#  Timestamp('2013-05-07 02:00:00'): 'down',
#  Timestamp('2013-05-08 07:00:00'): 'up',
#  Timestamp('2013-05-08 16:00:00'): 'down',
#  Timestamp('2013-05-08 22:00:00'): 'up',
#  Timestamp('2013-05-09 13:00:00'): 'down',
#  Timestamp('2013-05-10 17:00:00'): 'up',
#  Timestamp('2013-05-10 21:00:00'): 'down',
#  Timestamp('2013-05-13 05:00:00'): 'up',
#  Timestamp('2013-05-13 13:00:00'): 'down',
#  Timestamp('2013-05-13 19:00:00'): 'up',
#  Timestamp('2013-05-14 02:00:00'): 'down',
#  Timestamp('2013-05-14 22:00:00'): 'up',
#  Timestamp('2013-05-15 06:00:00'): 'down',
#  Timestamp('2013-05-15 08:00:00'): 'up',
#  Timestamp('2013-05-15 11:00:00'): 'down',
#  Timestamp('2013-05-15 17:00:00'): 'up',
#  Timestamp('2013-05-16 02:00:00'): 'down',
#  Timestamp('2013-05-16 10:00:00'): 'up',
#  Timestamp('2013-05-16 19:00:00'): 'down',
#  Timestamp('2013-05-17 21:00:00'): 'up',
#  Timestamp('2013-05-21 00:00:00'): 'down',
#  Timestamp('2013-05-21 15:00:00'): 'up',
#  Timestamp('2013-05-22 01:00:00'): 'down',
#  Timestamp('2013-05-23 03:00:00'): 'up',
#  Timestamp('2013-05-23 17:00:00'): 'down',
#  Timestamp('2013-05-24 04:00:00'): 'up',
#  Timestamp('2013-05-24 20:00:00'): 'down',
#  Timestamp('2013-05-27 03:00:00'): 'up',
#  Timestamp('2013-05-27 11:00:00'): 'down',
#  Timestamp('2013-05-27 17:00:00'): 'up',
#  Timestamp('2013-05-27 23:00:00'): 'down',
#  Timestamp('2013-05-28 02:00:00'): 'up',
#  Timestamp('2013-05-28 13:00:00'): 'down',
#  Timestamp('2013-05-29 07:00:00'): 'up',
#  Timestamp('2013-05-31 03:00:00'): 'down',
#  Timestamp('2013-05-31 16:00:00'): 'up',
#  Timestamp('2013-06-03 19:00:00'): 'down',
#  Timestamp('2013-06-03 21:00:00'): 'up',
#  Timestamp('2013-06-04 02:00:00'): 'down',
#  Timestamp('2013-06-04 16:00:00'): 'up',
#  Timestamp('2013-06-06 01:00:00'): 'down',
#  Timestamp('2013-06-06 03:00:00'): 'up',
#  Timestamp('2013-06-06 19:00:00'): 'down',
#  Timestamp('2013-06-07 00:00:00'): 'up',
#  Timestamp('2013-06-07 07:00:00'): 'down',
#  Timestamp('2013-06-07 16:00:00'): 'up',
#  Timestamp('2013-06-07 21:00:00'): 'down',
#  Timestamp('2013-06-10 09:00:00'): 'up',
#  Timestamp('2013-06-11 05:00:00'): 'down',
#  Timestamp('2013-06-11 15:00:00'): 'up',
#  Timestamp('2013-06-12 18:00:00'): 'down',
#  Timestamp('2013-06-13 00:00:00'): 'up',
#  Timestamp('2013-06-13 05:00:00'): 'down',
#  Timestamp('2013-06-13 12:00:00'): 'up',
#  Timestamp('2013-06-13 23:00:00'): 'down',
#  Timestamp('2013-06-14 11:00:00'): 'up',
#  Timestamp('2013-06-17 01:00:00'): 'down',
#  Timestamp('2013-06-17 08:00:00'): 'up',
#  Timestamp('2013-06-17 15:00:00'): 'down',
#  Timestamp('2013-06-17 20:00:00'): 'up',
#  Timestamp('2013-06-17 21:00:00'): 'down',
#  Timestamp('2013-06-18 14:00:00'): 'up',
#  Timestamp('2013-06-18 19:00:00'): 'down',
#  Timestamp('2013-06-19 11:00:00'): 'up',
#  Timestamp('2013-06-19 19:00:00'): 'down',
#  Timestamp('2013-06-20 08:00:00'): 'up',
#  Timestamp('2013-06-21 04:00:00'): 'down',
#  Timestamp('2013-06-24 11:00:00'): 'up',
#  Timestamp('2013-06-25 01:00:00'): 'down',
#  Timestamp('2013-06-25 05:00:00'): 'up',
#  Timestamp('2013-06-25 13:00:00'): 'down',
#  Timestamp('2013-06-26 04:00:00'): 'up',
#  Timestamp('2013-06-26 07:00:00'): 'down',
#  Timestamp('2013-06-26 22:00:00'): 'up',
#  Timestamp('2013-06-27 06:00:00'): 'down',
#  Timestamp('2013-06-27 17:00:00'): 'up',
#  Timestamp('2013-06-28 08:00:00'): 'down',
#  Timestamp('2013-06-28 17:00:00'): 'up',
#  Timestamp('2013-07-01 17:00:00'): 'down',
#  Timestamp('2013-07-03 08:00:00'): 'up',
#  Timestamp('2013-07-04 01:00:00'): 'down',
#  Timestamp('2013-07-08 01:00:00'): 'up',
#  Timestamp('2013-07-08 21:00:00'): 'down',
#  Timestamp('2013-07-09 02:00:00'): 'up',
#  Timestamp('2013-07-09 08:00:00'): 'down',
#  Timestamp('2013-07-09 16:00:00'): 'up',
#  Timestamp('2013-07-09 21:00:00'): 'down',
#  Timestamp('2013-07-10 01:00:00'): 'up',
#  Timestamp('2013-07-11 06:00:00'): 'down',
#  Timestamp('2013-07-11 09:00:00'): 'up',
#  Timestamp('2013-07-11 21:00:00'): 'down',
#  Timestamp('2013-07-12 14:00:00'): 'up',
#  Timestamp('2013-07-12 18:00:00'): 'down',
#  Timestamp('2013-07-15 00:00:00'): 'up',
#  Timestamp('2013-07-15 06:00:00'): 'down',
#  Timestamp('2013-07-15 13:00:00'): 'up',
#  Timestamp('2013-07-16 07:00:00'): 'down',
#  Timestamp('2013-07-16 10:00:00'): 'up',
#  Timestamp('2013-07-16 22:00:00'): 'down',
#  Timestamp('2013-07-17 08:00:00'): 'up',
#  Timestamp('2013-07-17 14:00:00'): 'down',
#  Timestamp('2013-07-17 16:00:00'): 'up',
#  Timestamp('2013-07-17 22:00:00'): 'down',
#  Timestamp('2013-07-18 09:00:00'): 'up',
#  Timestamp('2013-07-22 16:00:00'): 'down',
#  Timestamp('2013-07-22 21:00:00'): 'up',
#  Timestamp('2013-07-23 05:00:00'): 'down',
#  Timestamp('2013-07-23 13:00:00'): 'up',
#  Timestamp('2013-07-23 20:00:00'): 'down',
#  Timestamp('2013-07-25 01:00:00'): 'up',
#  Timestamp('2013-07-25 09:00:00'): 'down',
#  Timestamp('2013-07-25 11:00:00'): 'up',
#  Timestamp('2013-07-26 13:00:00'): 'down',
#  Timestamp('2013-07-26 17:00:00'): 'up',
#  Timestamp('2013-07-29 10:00:00'): 'down',
#  Timestamp('2013-07-31 15:00:00'): 'up',
#  Timestamp('2013-07-31 20:00:00'): 'down',
#  Timestamp('2013-08-01 08:00:00'): 'up',
#  Timestamp('2013-08-01 13:00:00'): 'down',
#  Timestamp('2013-08-02 03:00:00'): 'up',
#  Timestamp('2013-08-02 19:00:00'): 'down',
#  Timestamp('2013-08-05 06:00:00'): 'up',
#  Timestamp('2013-08-06 02:00:00'): 'down',
#  Timestamp('2013-08-06 08:00:00'): 'up',
#  Timestamp('2013-08-06 16:00:00'): 'down',
#  Timestamp('2013-08-07 09:00:00'): 'up',
#  Timestamp('2013-08-07 16:00:00'): 'down',
#  Timestamp('2013-08-08 04:00:00'): 'up',
#  Timestamp('2013-08-08 18:00:00'): 'down',
#  Timestamp('2013-08-09 01:00:00'): 'up',
#  Timestamp('2013-08-09 11:00:00'): 'down',
#  Timestamp('2013-08-13 02:00:00'): 'up',
#  Timestamp('2013-08-13 08:00:00'): 'down',
#  Timestamp('2013-08-14 09:00:00'): 'up',
#  Timestamp('2013-08-14 16:00:00'): 'down',
#  Timestamp('2013-08-14 22:00:00'): 'up',
#  Timestamp('2013-08-15 23:00:00'): 'down',
#  Timestamp('2013-08-16 07:00:00'): 'up',
#  Timestamp('2013-08-16 14:00:00'): 'down',
#  Timestamp('2013-08-19 00:00:00'): 'up',
#  Timestamp('2013-08-19 16:00:00'): 'down',
#  Timestamp('2013-08-20 08:00:00'): 'up',
#  Timestamp('2013-08-20 16:00:00'): 'down',
#  Timestamp('2013-08-21 02:00:00'): 'up',
#  Timestamp('2013-08-21 20:00:00'): 'down',
#  Timestamp('2013-08-22 11:00:00'): 'up',
#  Timestamp('2013-08-22 19:00:00'): 'down',
#  Timestamp('2013-08-22 20:00:00'): 'up',
#  Timestamp('2013-08-23 01:00:00'): 'down',
#  Timestamp('2013-08-23 09:00:00'): 'up',
#  Timestamp('2013-08-23 10:00:00'): 'down',
#  Timestamp('2013-08-23 18:00:00'): 'up',
#  Timestamp('2013-08-23 21:00:00'): 'down',
#  Timestamp('2013-08-23 22:00:00'): 'up',
#  Timestamp('2013-08-26 01:00:00'): 'down',
#  Timestamp('2013-08-26 13:00:00'): 'up',
#  Timestamp('2013-08-26 14:00:00'): 'down',
#  Timestamp('2013-08-26 19:00:00'): 'up',
#  Timestamp('2013-08-27 02:00:00'): 'down',
#  Timestamp('2013-08-27 13:00:00'): 'up',
#  Timestamp('2013-08-28 00:00:00'): 'down',
#  Timestamp('2013-08-28 13:00:00'): 'up',
#  Timestamp('2013-08-29 04:00:00'): 'down',
#  Timestamp('2013-08-29 17:00:00'): 'up',
#  Timestamp('2013-08-30 08:00:00'): 'down',
#  Timestamp('2013-08-30 17:00:00'): 'up',
#  Timestamp('2013-09-02 12:00:00'): 'down',
#  Timestamp('2013-09-02 18:00:00'): 'up',
#  Timestamp('2013-09-03 10:00:00'): 'down',
#  Timestamp('2013-09-03 16:00:00'): 'up',
#  Timestamp('2013-09-03 21:00:00'): 'down',
#  Timestamp('2013-09-04 03:00:00'): 'up',
#  Timestamp('2013-09-04 17:00:00'): 'down',
#  Timestamp('2013-09-05 09:00:00'): 'up',
#  Timestamp('2013-09-05 13:00:00'): 'down',
#  Timestamp('2013-09-05 23:00:00'): 'up',
#  Timestamp('2013-09-06 05:00:00'): 'down',
#  Timestamp('2013-09-06 12:00:00'): 'up',
#  Timestamp('2013-09-09 17:00:00'): 'down',
#  Timestamp('2013-09-10 08:00:00'): 'up',
#  Timestamp('2013-09-10 19:00:00'): 'down',
#  Timestamp('2013-09-11 07:00:00'): 'up',
#  Timestamp('2013-09-12 04:00:00'): 'down',
#  Timestamp('2013-09-12 10:00:00'): 'up',
#  Timestamp('2013-09-12 16:00:00'): 'down',
#  Timestamp('2013-09-13 07:00:00'): 'up',
#  Timestamp('2013-09-16 14:00:00'): 'down',
#  Timestamp('2013-09-17 03:00:00'): 'up',
#  Timestamp('2013-09-17 09:00:00'): 'down',
#  Timestamp('2013-09-17 17:00:00'): 'up',
#  Timestamp('2013-09-17 20:00:00'): 'down',
#  Timestamp('2013-09-18 03:00:00'): 'up',
#  Timestamp('2013-09-19 03:00:00'): 'down',
#  Timestamp('2013-09-20 01:00:00'): 'up',
#  Timestamp('2013-09-20 09:00:00'): 'down',
#  Timestamp('2013-09-23 00:00:00'): 'up',
#  Timestamp('2013-09-23 14:00:00'): 'down',
#  Timestamp('2013-09-23 16:00:00'): 'up',
#  Timestamp('2013-09-23 18:00:00'): 'down',
#  Timestamp('2013-09-24 14:00:00'): 'up',
#  Timestamp('2013-09-24 19:00:00'): 'down',
#  Timestamp('2013-09-25 05:00:00'): 'up',
#  Timestamp('2013-09-25 21:00:00'): 'down',
#  Timestamp('2013-09-26 03:00:00'): 'up',
#  Timestamp('2013-09-26 09:00:00'): 'down',
#  Timestamp('2013-09-26 16:00:00'): 'up',
#  Timestamp('2013-09-30 04:00:00'): 'down',
#  Timestamp('2013-09-30 09:00:00'): 'up',
#  Timestamp('2013-10-01 08:00:00'): 'down',
#  Timestamp('2013-10-02 03:00:00'): 'up',
#  Timestamp('2013-10-02 14:00:00'): 'down',
#  Timestamp('2013-10-02 19:00:00'): 'up',
#  Timestamp('2013-10-03 06:00:00'): 'down',
#  Timestamp('2013-10-03 22:00:00'): 'up',
#  Timestamp('2013-10-04 06:00:00'): 'down',
#  Timestamp('2013-10-04 22:00:00'): 'up',
#  Timestamp('2013-10-08 01:00:00'): 'down',
#  Timestamp('2013-10-08 10:00:00'): 'up',
#  Timestamp('2013-10-08 15:00:00'): 'down',
#  Timestamp('2013-10-08 18:00:00'): 'up',
#  Timestamp('2013-10-09 01:00:00'): 'down',
#  Timestamp('2013-10-09 14:00:00'): 'up',
#  Timestamp('2013-10-10 00:00:00'): 'down',
#  Timestamp('2013-10-10 06:00:00'): 'up',
#  Timestamp('2013-10-11 09:00:00'): 'down',
#  Timestamp('2013-10-11 18:00:00'): 'up',
#  Timestamp('2013-10-14 07:00:00'): 'down',
#  Timestamp('2013-10-14 10:00:00'): 'up',
#  Timestamp('2013-10-14 16:00:00'): 'down',
#  Timestamp('2013-10-15 02:00:00'): 'up',
#  Timestamp('2013-10-15 06:00:00'): 'down',
#  Timestamp('2013-10-15 12:00:00'): 'up',
#  Timestamp('2013-10-15 23:00:00'): 'down',
#  Timestamp('2013-10-16 05:00:00'): 'up',
#  Timestamp('2013-10-16 13:00:00'): 'down',
#  Timestamp('2013-10-16 17:00:00'): 'up',
#  Timestamp('2013-10-17 21:00:00'): 'down',
#  Timestamp('2013-10-18 03:00:00'): 'up',
#  Timestamp('2013-10-18 11:00:00'): 'down',
#  Timestamp('2013-10-21 05:00:00'): 'up',
#  Timestamp('2013-10-21 09:00:00'): 'down',
#  Timestamp('2013-10-22 05:00:00'): 'up',
#  Timestamp('2013-10-23 04:00:00'): 'down',
#  Timestamp('2013-10-23 12:00:00'): 'up',
#  Timestamp('2013-10-23 19:00:00'): 'down',
#  Timestamp('2013-10-24 01:00:00'): 'up',
#  Timestamp('2013-10-24 07:00:00'): 'down',
#  Timestamp('2013-10-24 14:00:00'): 'up',
#  Timestamp('2013-10-24 19:00:00'): 'down',
#  Timestamp('2013-10-25 02:00:00'): 'up',
#  Timestamp('2013-10-25 06:00:00'): 'down',
#  Timestamp('2013-10-25 17:00:00'): 'up',
#  Timestamp('2013-10-28 11:00:00'): 'down',
#  Timestamp('2013-10-30 03:00:00'): 'up',
#  Timestamp('2013-10-30 16:00:00'): 'down',
#  Timestamp('2013-10-31 07:00:00'): 'up',
#  Timestamp('2013-10-31 16:00:00'): 'down',
#  Timestamp('2013-11-04 04:00:00'): 'up',
#  Timestamp('2013-11-04 13:00:00'): 'down',
#  Timestamp('2013-11-04 17:00:00'): 'up',
#  Timestamp('2013-11-05 01:00:00'): 'down',
#  Timestamp('2013-11-05 07:00:00'): 'up',
#  Timestamp('2013-11-05 13:00:00'): 'down',
#  Timestamp('2013-11-05 18:00:00'): 'up',
#  Timestamp('2013-11-06 15:00:00'): 'down',
#  Timestamp('2013-11-07 01:00:00'): 'up',
#  Timestamp('2013-11-07 08:00:00'): 'down',
#  Timestamp('2013-11-07 14:00:00'): 'up',
#  Timestamp('2013-11-08 02:00:00'): 'down',
#  Timestamp('2013-11-08 17:00:00'): 'up',
#  Timestamp('2013-11-11 10:00:00'): 'down',
#  Timestamp('2013-11-11 16:00:00'): 'up',
#  Timestamp('2013-11-11 21:00:00'): 'down',
#  Timestamp('2013-11-12 10:00:00'): 'up',
#  Timestamp('2013-11-12 15:00:00'): 'down',
#  Timestamp('2013-11-13 08:00:00'): 'up',
#  Timestamp('2013-11-13 22:00:00'): 'down',
#  Timestamp('2013-11-14 11:00:00'): 'up',
#  Timestamp('2013-11-14 16:00:00'): 'down',
#  Timestamp('2013-11-15 00:00:00'): 'up',
#  Timestamp('2013-11-15 08:00:00'): 'down',
#  Timestamp('2013-11-15 10:00:00'): 'up',
#  Timestamp('2013-11-18 09:00:00'): 'down',
#  Timestamp('2013-11-18 20:00:00'): 'up',
#  Timestamp('2013-11-19 02:00:00'): 'down',
#  Timestamp('2013-11-19 12:00:00'): 'up',
#  Timestamp('2013-11-20 00:00:00'): 'down',
#  Timestamp('2013-11-20 04:00:00'): 'up',
#  Timestamp('2013-11-20 16:00:00'): 'down',
#  Timestamp('2013-11-21 05:00:00'): 'up',
#  Timestamp('2013-11-22 22:00:00'): 'down',
#  Timestamp('2013-11-25 17:00:00'): 'up',
#  Timestamp('2013-11-26 00:00:00'): 'down',
#  Timestamp('2013-11-26 04:00:00'): 'up',
#  Timestamp('2013-11-26 09:00:00'): 'down',
#  Timestamp('2013-11-26 14:00:00'): 'up',
#  Timestamp('2013-11-27 14:00:00'): 'down',
#  Timestamp('2013-11-27 17:00:00'): 'up',
#  Timestamp('2013-11-28 15:00:00'): 'down',
#  Timestamp('2013-11-28 18:00:00'): 'up',
#  Timestamp('2013-11-29 02:00:00'): 'down',
#  Timestamp('2013-11-29 10:00:00'): 'up',
#  Timestamp('2013-12-02 02:00:00'): 'down',
#  Timestamp('2013-12-02 20:00:00'): 'up',
#  Timestamp('2013-12-03 12:00:00'): 'down',
#  Timestamp('2013-12-03 23:00:00'): 'up',
#  Timestamp('2013-12-04 05:00:00'): 'down',
#  Timestamp('2013-12-04 14:00:00'): 'up',
#  Timestamp('2013-12-04 21:00:00'): 'down',
#  Timestamp('2013-12-05 01:00:00'): 'up',
#  Timestamp('2013-12-05 08:00:00'): 'down',
#  Timestamp('2013-12-05 16:00:00'): 'up',
#  Timestamp('2013-12-05 23:00:00'): 'down',
#  Timestamp('2013-12-06 07:00:00'): 'up',
#  Timestamp('2013-12-06 11:00:00'): 'down',
#  Timestamp('2013-12-09 00:00:00'): 'up',
#  Timestamp('2013-12-10 05:00:00'): 'down',
#  Timestamp('2013-12-10 17:00:00'): 'up',
#  Timestamp('2013-12-11 00:00:00'): 'down',
#  Timestamp('2013-12-11 16:00:00'): 'up',
#  Timestamp('2013-12-11 18:00:00'): 'down',
#  Timestamp('2013-12-12 01:00:00'): 'up',
#  Timestamp('2013-12-12 13:00:00'): 'down',
#  Timestamp('2013-12-12 16:00:00'): 'up',
#  Timestamp('2013-12-13 04:00:00'): 'down',
#  Timestamp('2013-12-13 15:00:00'): 'up',
#  Timestamp('2013-12-16 13:00:00'): 'down',
#  Timestamp('2013-12-16 22:00:00'): 'up',
#  Timestamp('2013-12-17 09:00:00'): 'down',
#  Timestamp('2013-12-17 16:00:00'): 'up',
#  Timestamp('2013-12-18 20:00:00'): 'down',
#  Timestamp('2013-12-19 03:00:00'): 'up',
#  Timestamp('2013-12-19 08:00:00'): 'down',
#  Timestamp('2013-12-19 14:00:00'): 'up',
#  Timestamp('2013-12-19 19:00:00'): 'down',
#  Timestamp('2013-12-20 14:00:00'): 'up',
#  Timestamp('2013-12-20 15:00:00'): 'down',
#  Timestamp('2013-12-20 22:00:00'): 'up',
#  Timestamp('2013-12-23 08:00:00'): 'down',
#  Timestamp('2013-12-23 14:00:00'): 'up',
#  Timestamp('2013-12-23 18:00:00'): 'down',
#  Timestamp('2013-12-24 09:00:00'): 'up',
#  Timestamp('2013-12-26 16:00:00'): 'down',
#  Timestamp('2013-12-26 22:00:00'): 'up',
#  Timestamp('2013-12-27 12:00:00'): 'down',
#  Timestamp('2013-12-30 12:00:00'): 'up',
#  Timestamp('2013-12-30 16:00:00'): 'down',
#  Timestamp('2013-12-31 04:00:00'): 'up',
#  Timestamp('2014-01-02 06:00:00'): 'down',
#  Timestamp('2014-01-02 20:00:00'): 'up',
#  Timestamp('2014-01-03 01:00:00'): 'down',
#  Timestamp('2014-01-03 03:00:00'): 'up',
#  Timestamp('2014-01-03 11:00:00'): 'down',
#  Timestamp('2014-01-06 08:00:00'): 'up',
#  Timestamp('2014-01-06 19:00:00'): 'down',
#  Timestamp('2014-01-07 09:00:00'): 'up',
#  Timestamp('2014-01-07 18:00:00'): 'down',
#  Timestamp('2014-01-08 01:00:00'): 'up',
#  Timestamp('2014-01-08 16:00:00'): 'down',
#  Timestamp('2014-01-08 23:00:00'): 'up',
#  Timestamp('2014-01-10 05:00:00'): 'down',
#  Timestamp('2014-01-10 11:00:00'): 'up',
#  Timestamp('2014-01-13 04:00:00'): 'down',
#  Timestamp('2014-01-13 19:00:00'): 'up',
#  Timestamp('2014-01-14 16:00:00'): 'down',
#  Timestamp('2014-01-15 15:00:00'): 'up',
#  Timestamp('2014-01-15 21:00:00'): 'down',
#  Timestamp('2014-01-16 11:00:00'): 'up',
#  Timestamp('2014-01-16 14:00:00'): 'down',
#  Timestamp('2014-01-16 17:00:00'): 'up',
#  Timestamp('2014-01-16 20:00:00'): 'down',
#  Timestamp('2014-01-17 08:00:00'): 'up',
#  Timestamp('2014-01-17 13:00:00'): 'down',
#  Timestamp('2014-01-20 01:00:00'): 'up',
#  Timestamp('2014-01-20 10:00:00'): 'down',
#  Timestamp('2014-01-20 17:00:00'): 'up',
#  Timestamp('2014-01-20 21:00:00'): 'down',
#  Timestamp('2014-01-21 02:00:00'): 'up',
#  Timestamp('2014-01-21 07:00:00'): 'down',
#  Timestamp('2014-01-21 12:00:00'): 'up',
#  Timestamp('2014-01-22 01:00:00'): 'down',
#  Timestamp('2014-01-22 09:00:00'): 'up',
#  Timestamp('2014-01-22 21:00:00'): 'down',
#  Timestamp('2014-01-23 00:00:00'): 'up',
#  Timestamp('2014-01-23 23:00:00'): 'down',
#  Timestamp('2014-01-24 07:00:00'): 'up',
#  Timestamp('2014-01-24 08:00:00'): 'down',
#  Timestamp('2014-01-24 22:00:00'): 'up',
#  Timestamp('2014-01-28 07:00:00'): 'down',
#  Timestamp('2014-01-28 11:00:00'): 'up',
#  Timestamp('2014-01-28 14:00:00'): 'down',
#  Timestamp('2014-01-28 23:00:00'): 'up',
#  Timestamp('2014-01-29 09:00:00'): 'down',
#  Timestamp('2014-01-29 14:00:00'): 'up',
#  Timestamp('2014-01-29 19:00:00'): 'down',
#  Timestamp('2014-01-30 10:00:00'): 'up',
#  Timestamp('2014-01-30 14:00:00'): 'down',
#  Timestamp('2014-01-30 21:00:00'): 'up',
#  Timestamp('2014-01-31 00:00:00'): 'down',
#  Timestamp('2014-02-04 07:00:00'): 'up',
#  Timestamp('2014-02-04 10:00:00'): 'down',
#  Timestamp('2014-02-04 16:00:00'): 'up',
#  Timestamp('2014-02-05 06:00:00'): 'down',
#  Timestamp('2014-02-05 13:00:00'): 'up',
#  Timestamp('2014-02-06 00:00:00'): 'down',
#  Timestamp('2014-02-06 11:00:00'): 'up',
#  Timestamp('2014-02-06 17:00:00'): 'down',
#  Timestamp('2014-02-06 23:00:00'): 'up',
#  Timestamp('2014-02-10 03:00:00'): 'down',
#  Timestamp('2014-02-10 11:00:00'): 'up',
#  Timestamp('2014-02-11 05:00:00'): 'down',
#  Timestamp('2014-02-11 08:00:00'): 'up',
#  Timestamp('2014-02-11 16:00:00'): 'down',
#  Timestamp('2014-02-12 08:00:00'): 'up',
#  Timestamp('2014-02-13 22:00:00'): 'down',
#  Timestamp('2014-02-14 06:00:00'): 'up',
#  Timestamp('2014-02-17 02:00:00'): 'down',
#  Timestamp('2014-02-17 20:00:00'): 'up',
#  Timestamp('2014-02-18 05:00:00'): 'down',
#  Timestamp('2014-02-18 13:00:00'): 'up',
#  Timestamp('2014-02-18 15:00:00'): 'down',
#  Timestamp('2014-02-18 21:00:00'): 'up',
#  Timestamp('2014-02-19 09:00:00'): 'down',
#  Timestamp('2014-02-19 13:00:00'): 'up',
#  Timestamp('2014-02-19 18:00:00'): 'down',
#  Timestamp('2014-02-20 10:00:00'): 'up',
#  Timestamp('2014-02-20 14:00:00'): 'down',
#  Timestamp('2014-02-20 17:00:00'): 'up',
#  Timestamp('2014-02-21 02:00:00'): 'down',
#  Timestamp('2014-02-21 06:00:00'): 'up',
#  Timestamp('2014-02-21 15:00:00'): 'down',
#  Timestamp('2014-02-21 22:00:00'): 'up',
#  Timestamp('2014-02-24 10:00:00'): 'down',
#  Timestamp('2014-02-24 15:00:00'): 'up',
#  Timestamp('2014-02-25 15:00:00'): 'down',
#  Timestamp('2014-02-26 08:00:00'): 'up',
#  Timestamp('2014-02-26 09:00:00'): 'down',
#  Timestamp('2014-02-26 18:00:00'): 'up',
#  Timestamp('2014-02-27 02:00:00'): 'down',
#  Timestamp('2014-02-27 11:00:00'): 'up',
#  Timestamp('2014-02-28 02:00:00'): 'down',
#  Timestamp('2014-02-28 04:00:00'): 'up',
#  Timestamp('2014-02-28 20:00:00'): 'down',
#  Timestamp('2014-03-04 02:00:00'): 'up',
#  Timestamp('2014-03-04 13:00:00'): 'down',
#  Timestamp('2014-03-04 23:00:00'): 'up',
#  Timestamp('2014-03-05 18:00:00'): 'down',
#  Timestamp('2014-03-06 13:00:00'): 'up',
#  Timestamp('2014-03-06 18:00:00'): 'down',
#  Timestamp('2014-03-07 08:00:00'): 'up',
#  Timestamp('2014-03-07 13:00:00'): 'down',
#  Timestamp('2014-03-07 22:00:00'): 'up',
#  Timestamp('2014-03-10 01:00:00'): 'down',
#  Timestamp('2014-03-10 16:00:00'): 'up',
#  Timestamp('2014-03-11 07:00:00'): 'down',
#  Timestamp('2014-03-11 12:00:00'): 'up',
#  Timestamp('2014-03-11 17:00:00'): 'down',
#  Timestamp('2014-03-11 20:00:00'): 'up',
#  Timestamp('2014-03-12 07:00:00'): 'down',
#  Timestamp('2014-03-12 11:00:00'): 'up',
#  Timestamp('2014-03-13 12:00:00'): 'down',
#  Timestamp('2014-03-14 12:00:00'): 'up',
#  Timestamp('2014-03-17 09:00:00'): 'down',
#  Timestamp('2014-03-17 12:00:00'): 'up',
#  Timestamp('2014-03-17 14:00:00'): 'down',
#  Timestamp('2014-03-17 22:00:00'): 'up',
#  Timestamp('2014-03-18 07:00:00'): 'down',
#  Timestamp('2014-03-18 15:00:00'): 'up',
#  Timestamp('2014-03-19 12:00:00'): 'down',
#  Timestamp('2014-03-19 22:00:00'): 'up',
#  Timestamp('2014-03-20 09:00:00'): 'down',
#  Timestamp('2014-03-20 15:00:00'): 'up',
#  Timestamp('2014-03-21 03:00:00'): 'down',
#  Timestamp('2014-03-24 15:00:00'): 'up',
#  Timestamp('2014-03-24 18:00:00'): 'down',
#  Timestamp('2014-03-25 06:00:00'): 'up',
#  Timestamp('2014-03-26 02:00:00'): 'down',
#  Timestamp('2014-03-26 07:00:00'): 'up',
#  Timestamp('2014-03-27 03:00:00'): 'down',
#  Timestamp('2014-03-27 09:00:00'): 'up',
#  Timestamp('2014-03-27 15:00:00'): 'down',
#  Timestamp('2014-03-27 22:00:00'): 'up',
#  Timestamp('2014-03-28 18:00:00'): 'down',
#  Timestamp('2014-03-31 05:00:00'): 'up',
#  Timestamp('2014-03-31 18:00:00'): 'down',
#  Timestamp('2014-04-01 03:00:00'): 'up',
#  Timestamp('2014-04-01 08:00:00'): 'down',
#  Timestamp('2014-04-02 05:00:00'): 'up',
#  Timestamp('2014-04-02 13:00:00'): 'down',
#  Timestamp('2014-04-03 00:00:00'): 'up',
#  Timestamp('2014-04-03 03:00:00'): 'down',
#  Timestamp('2014-04-03 17:00:00'): 'up',
#  Timestamp('2014-04-04 01:00:00'): 'down',
#  Timestamp('2014-04-04 13:00:00'): 'up',
#  Timestamp('2014-04-04 17:00:00'): 'down',
#  Timestamp('2014-04-07 09:00:00'): 'up',
#  Timestamp('2014-04-08 23:00:00'): 'down',
#  Timestamp('2014-04-09 10:00:00'): 'up',
#  Timestamp('2014-04-10 02:00:00'): 'down',
#  Timestamp('2014-04-10 15:00:00'): 'up',
#  Timestamp('2014-04-10 20:00:00'): 'down',
#  Timestamp('2014-04-11 16:00:00'): 'up',
#  Timestamp('2014-04-11 20:00:00'): 'down',
#  Timestamp('2014-04-14 02:00:00'): 'up',
#  Timestamp('2014-04-14 07:00:00'): 'down',
#  Timestamp('2014-04-14 14:00:00'): 'up',
#  Timestamp('2014-04-14 17:00:00'): 'down',
#  Timestamp('2014-04-15 08:00:00'): 'up',
#  Timestamp('2014-04-15 15:00:00'): 'down',
#  Timestamp('2014-04-15 20:00:00'): 'up',
#  Timestamp('2014-04-17 05:00:00'): 'down',
#  Timestamp('2014-04-18 01:00:00'): 'up',
#  Timestamp('2014-04-18 04:00:00'): 'down',
#  Timestamp('2014-04-18 11:00:00'): 'up',
#  Timestamp('2014-04-18 15:00:00'): 'down',
#  Timestamp('2014-04-18 20:00:00'): 'up',
#  Timestamp('2014-04-21 10:00:00'): 'down',
#  Timestamp('2014-04-22 02:00:00'): 'up',
#  Timestamp('2014-04-22 17:00:00'): 'down',
#  Timestamp('2014-04-22 20:00:00'): 'up',
#  Timestamp('2014-04-23 04:00:00'): 'down',
#  Timestamp('2014-04-23 17:00:00'): 'up',
#  Timestamp('2014-04-24 08:00:00'): 'down',
#  Timestamp('2014-04-24 14:00:00'): 'up',
#  Timestamp('2014-04-25 15:00:00'): 'down',
#  Timestamp('2014-04-28 02:00:00'): 'up',
#  Timestamp('2014-04-28 11:00:00'): 'down',
#  Timestamp('2014-04-28 22:00:00'): 'up',
#  Timestamp('2014-04-29 09:00:00'): 'down',
#  Timestamp('2014-04-29 12:00:00'): 'up',
#  Timestamp('2014-04-29 16:00:00'): 'down',
#  Timestamp('2014-04-30 07:00:00'): 'up',
#  Timestamp('2014-04-30 20:00:00'): 'down',
#  Timestamp('2014-04-30 22:00:00'): 'up',
#  Timestamp('2014-05-01 11:00:00'): 'down',
#  Timestamp('2014-05-02 15:00:00'): 'up',
#  Timestamp('2014-05-05 03:00:00'): 'down',
#  Timestamp('2014-05-05 15:00:00'): 'up',
#  Timestamp('2014-05-06 16:00:00'): 'down',
#  Timestamp('2014-05-07 04:00:00'): 'up',
#  Timestamp('2014-05-07 05:00:00'): 'down',
#  Timestamp('2014-05-08 04:00:00'): 'up',
#  Timestamp('2014-05-08 12:00:00'): 'down',
#  Timestamp('2014-05-09 20:00:00'): 'up',
#  Timestamp('2014-05-12 11:00:00'): 'down',
#  Timestamp('2014-05-12 20:00:00'): 'up',
#  Timestamp('2014-05-13 02:00:00'): 'down',
#  Timestamp('2014-05-13 20:00:00'): 'up',
#  Timestamp('2014-05-14 09:00:00'): 'down',
#  Timestamp('2014-05-14 23:00:00'): 'up',
#  Timestamp('2014-05-15 05:00:00'): 'down',
#  Timestamp('2014-05-15 09:00:00'): 'up',
#  Timestamp('2014-05-15 20:00:00'): 'down',
#  Timestamp('2014-05-16 02:00:00'): 'up',
#  Timestamp('2014-05-16 15:00:00'): 'down',
#  Timestamp('2014-05-16 22:00:00'): 'up',
#  Timestamp('2014-05-19 07:00:00'): 'down',
#  Timestamp('2014-05-19 10:00:00'): 'up',
#  Timestamp('2014-05-19 13:00:00'): 'down',
#  Timestamp('2014-05-20 08:00:00'): 'up',
#  Timestamp('2014-05-20 16:00:00'): 'down',
#  Timestamp('2014-05-21 02:00:00'): 'up',
#  Timestamp('2014-05-21 13:00:00'): 'down',
#  Timestamp('2014-05-21 17:00:00'): 'up',
#  Timestamp('2014-05-22 09:00:00'): 'down',
#  Timestamp('2014-05-22 19:00:00'): 'up',
#  Timestamp('2014-05-22 23:00:00'): 'down',
#  Timestamp('2014-05-23 02:00:00'): 'up',
#  Timestamp('2014-05-23 08:00:00'): 'down',
#  Timestamp('2014-05-23 18:00:00'): 'up',
#  Timestamp('2014-05-26 09:00:00'): 'down',
#  Timestamp('2014-05-26 14:00:00'): 'up',
#  Timestamp('2014-05-27 09:00:00'): 'down',
#  Timestamp('2014-05-27 18:00:00'): 'up',
#  Timestamp('2014-05-28 02:00:00'): 'down',
#  Timestamp('2014-05-28 19:00:00'): 'up',
#  Timestamp('2014-05-29 10:00:00'): 'down',
#  Timestamp('2014-05-29 19:00:00'): 'up',
#  Timestamp('2014-05-30 19:00:00'): 'down',
#  Timestamp('2014-06-02 10:00:00'): 'up',
#  Timestamp('2014-06-02 16:00:00'): 'down',
#  Timestamp('2014-06-03 05:00:00'): 'up',
#  Timestamp('2014-06-03 09:00:00'): 'down',
#  Timestamp('2014-06-03 16:00:00'): 'up',
#  Timestamp('2014-06-03 18:00:00'): 'down',
#  Timestamp('2014-06-04 09:00:00'): 'up',
#  Timestamp('2014-06-04 14:00:00'): 'down',
#  Timestamp('2014-06-04 23:00:00'): 'up',
#  Timestamp('2014-06-05 22:00:00'): 'down',
#  Timestamp('2014-06-06 11:00:00'): 'up',
#  Timestamp('2014-06-06 14:00:00'): 'down',
#  Timestamp('2014-06-06 16:00:00'): 'up',
#  Timestamp('2014-06-09 08:00:00'): 'down',
#  Timestamp('2014-06-09 19:00:00'): 'up',
#  Timestamp('2014-06-10 03:00:00'): 'down',
#  Timestamp('2014-06-11 04:00:00'): 'up',
#  Timestamp('2014-06-11 18:00:00'): 'down',
#  Timestamp('2014-06-11 22:00:00'): 'up',
#  Timestamp('2014-06-13 10:00:00'): 'down',
#  Timestamp('2014-06-13 17:00:00'): 'up',
#  Timestamp('2014-06-16 07:00:00'): 'down',
#  Timestamp('2014-06-16 12:00:00'): 'up',
#  Timestamp('2014-06-16 15:00:00'): 'down',
#  Timestamp('2014-06-17 03:00:00'): 'up',
#  Timestamp('2014-06-17 12:00:00'): 'down',
#  Timestamp('2014-06-17 20:00:00'): 'up',
#  Timestamp('2014-06-18 09:00:00'): 'down',
#  Timestamp('2014-06-18 16:00:00'): 'up',
#  Timestamp('2014-06-19 16:00:00'): 'down',
#  Timestamp('2014-06-19 21:00:00'): 'up',
#  Timestamp('2014-06-20 10:00:00'): 'down',
#  Timestamp('2014-06-20 19:00:00'): 'up',
#  Timestamp('2014-06-23 06:00:00'): 'down',
#  Timestamp('2014-06-23 13:00:00'): 'up',
#  Timestamp('2014-06-24 00:00:00'): 'down',
#  Timestamp('2014-06-24 17:00:00'): 'up',
#  Timestamp('2014-06-24 22:00:00'): 'down',
#  Timestamp('2014-06-25 09:00:00'): 'up',
#  Timestamp('2014-06-25 14:00:00'): 'down',
#  Timestamp('2014-06-25 19:00:00'): 'up',
#  Timestamp('2014-06-27 05:00:00'): 'down',
#  Timestamp('2014-06-27 15:00:00'): 'up',
#  Timestamp('2014-06-27 21:00:00'): 'down',
#  Timestamp('2014-06-30 08:00:00'): 'up',
#  Timestamp('2014-06-30 21:00:00'): 'down',
#  Timestamp('2014-07-01 08:00:00'): 'up',
#  Timestamp('2014-07-01 18:00:00'): 'down',
#  Timestamp('2014-07-02 02:00:00'): 'up',
#  Timestamp('2014-07-02 22:00:00'): 'down',
#  Timestamp('2014-07-03 14:00:00'): 'up',
#  Timestamp('2014-07-04 07:00:00'): 'down',
#  Timestamp('2014-07-04 11:00:00'): 'up',
#  Timestamp('2014-07-04 22:00:00'): 'down',
#  Timestamp('2014-07-07 14:00:00'): 'up',
#  Timestamp('2014-07-08 03:00:00'): 'down',
#  Timestamp('2014-07-08 10:00:00'): 'up',
#  Timestamp('2014-07-09 01:00:00'): 'down',
#  Timestamp('2014-07-09 14:00:00'): 'up',
#  Timestamp('2014-07-10 03:00:00'): 'down',
#  Timestamp('2014-07-10 12:00:00'): 'up',
#  Timestamp('2014-07-10 20:00:00'): 'down',
#  Timestamp('2014-07-11 02:00:00'): 'up',
#  Timestamp('2014-07-11 11:00:00'): 'down',
#  Timestamp('2014-07-11 16:00:00'): 'up',
#  Timestamp('2014-07-14 01:00:00'): 'down',
#  Timestamp('2014-07-14 05:00:00'): 'up',
#  Timestamp('2014-07-14 09:00:00'): 'down',
#  Timestamp('2014-07-14 19:00:00'): 'up',
#  Timestamp('2014-07-15 00:00:00'): 'down',
#  Timestamp('2014-07-15 08:00:00'): 'up',
#  Timestamp('2014-07-15 15:00:00'): 'down',
#  Timestamp('2014-07-16 10:00:00'): 'up',
#  Timestamp('2014-07-16 16:00:00'): 'down',
#  Timestamp('2014-07-16 17:00:00'): 'up',
#  Timestamp('2014-07-17 06:00:00'): 'down',
#  Timestamp('2014-07-17 16:00:00'): 'up',
#  Timestamp('2014-07-17 20:00:00'): 'down',
#  Timestamp('2014-07-18 02:00:00'): 'up',
#  Timestamp('2014-07-18 10:00:00'): 'down',
#  Timestamp('2014-07-18 14:00:00'): 'up',
#  Timestamp('2014-07-21 06:00:00'): 'down',
#  Timestamp('2014-07-21 15:00:00'): 'up',
#  Timestamp('2014-07-22 06:00:00'): 'down',
#  Timestamp('2014-07-22 18:00:00'): 'up',
#  Timestamp('2014-07-23 09:00:00'): 'down',
#  Timestamp('2014-07-23 20:00:00'): 'up',
#  Timestamp('2014-07-23 22:00:00'): 'down',
#  Timestamp('2014-07-24 15:00:00'): 'up',
#  Timestamp('2014-07-25 15:00:00'): 'down',
#  Timestamp('2014-07-25 18:00:00'): 'up',
#  Timestamp('2014-07-28 16:00:00'): 'down',
#  Timestamp('2014-07-29 23:00:00'): 'up',
#  Timestamp('2014-07-30 03:00:00'): 'down',
#  Timestamp('2014-07-30 19:00:00'): 'up',
#  Timestamp('2014-07-31 07:00:00'): 'down',
#  Timestamp('2014-07-31 14:00:00'): 'up',
#  Timestamp('2014-08-01 01:00:00'): 'down',
#  Timestamp('2014-08-04 00:00:00'): 'up',
#  Timestamp('2014-08-05 02:00:00'): 'down',
#  Timestamp('2014-08-05 09:00:00'): 'up',
#  Timestamp('2014-08-05 10:00:00'): 'down',
#  Timestamp('2014-08-05 14:00:00'): 'up',
#  Timestamp('2014-08-05 22:00:00'): 'down',
#  Timestamp('2014-08-06 12:00:00'): 'up',
#  Timestamp('2014-08-07 03:00:00'): 'down',
#  Timestamp('2014-08-08 22:00:00'): 'up',
#  Timestamp('2014-08-11 14:00:00'): 'down',
#  Timestamp('2014-08-11 18:00:00'): 'up',
#  Timestamp('2014-08-11 21:00:00'): 'down',
#  Timestamp('2014-08-12 07:00:00'): 'up',
#  Timestamp('2014-08-12 19:00:00'): 'down',
#  Timestamp('2014-08-13 04:00:00'): 'up',
#  Timestamp('2014-08-13 09:00:00'): 'down',
#  Timestamp('2014-08-14 09:00:00'): 'up',
#  Timestamp('2014-08-14 17:00:00'): 'down',
#  Timestamp('2014-08-15 09:00:00'): 'up',
#  Timestamp('2014-08-15 15:00:00'): 'down',
#  Timestamp('2014-08-15 18:00:00'): 'up',
#  Timestamp('2014-08-18 09:00:00'): 'down',
#  Timestamp('2014-08-18 17:00:00'): 'up',
#  Timestamp('2014-08-18 19:00:00'): 'down',
#  Timestamp('2014-08-19 23:00:00'): 'up',
#  Timestamp('2014-08-20 03:00:00'): 'down',
#  Timestamp('2014-08-20 07:00:00'): 'up',
#  Timestamp('2014-08-20 15:00:00'): 'down',
#  Timestamp('2014-08-21 06:00:00'): 'up',
#  Timestamp('2014-08-21 16:00:00'): 'down',
#  Timestamp('2014-08-22 02:00:00'): 'up',
#  Timestamp('2014-08-22 09:00:00'): 'down',
#  Timestamp('2014-08-22 22:00:00'): 'up',
#  Timestamp('2014-08-25 12:00:00'): 'down',
#  Timestamp('2014-08-26 00:00:00'): 'up',
#  Timestamp('2014-08-26 04:00:00'): 'down',
#  Timestamp('2014-08-26 22:00:00'): 'up',
#  Timestamp('2014-08-27 14:00:00'): 'down',
#  Timestamp('2014-08-27 21:00:00'): 'up',
#  Timestamp('2014-08-28 06:00:00'): 'down',
#  Timestamp('2014-08-28 18:00:00'): 'up',
#  Timestamp('2014-08-29 01:00:00'): 'down',
#  Timestamp('2014-08-29 07:00:00'): 'up',
#  Timestamp('2014-08-29 16:00:00'): 'down',
#  Timestamp('2014-08-29 20:00:00'): 'up',
#  Timestamp('2014-09-01 08:00:00'): 'down',
#  Timestamp('2014-09-03 05:00:00'): 'up',
#  Timestamp('2014-09-03 10:00:00'): 'down',
#  Timestamp('2014-09-03 20:00:00'): 'up',
#  Timestamp('2014-09-04 00:00:00'): 'down',
#  Timestamp('2014-09-05 01:00:00'): 'up',
#  Timestamp('2014-09-05 08:00:00'): 'down',
#  Timestamp('2014-09-05 13:00:00'): 'up',
#  Timestamp('2014-09-05 20:00:00'): 'down',
#  Timestamp('2014-09-08 11:00:00'): 'up',
#  Timestamp('2014-09-08 16:00:00'): 'down',
#  Timestamp('2014-09-09 06:00:00'): 'up',
#  Timestamp('2014-09-09 12:00:00'): 'down',
#  Timestamp('2014-09-09 18:00:00'): 'up',
#  Timestamp('2014-09-10 08:00:00'): 'down',
#  Timestamp('2014-09-10 10:00:00'): 'up',
#  Timestamp('2014-09-11 02:00:00'): 'down',
#  Timestamp('2014-09-11 07:00:00'): 'up',
#  Timestamp('2014-09-11 14:00:00'): 'down',
#  Timestamp('2014-09-11 15:00:00'): 'up',
#  Timestamp('2014-09-11 23:00:00'): 'down',
#  Timestamp('2014-09-12 07:00:00'): 'up',
#  Timestamp('2014-09-12 11:00:00'): 'down',
#  Timestamp('2014-09-12 15:00:00'): 'up',
#  Timestamp('2014-09-12 22:00:00'): 'down',
#  Timestamp('2014-09-15 06:00:00'): 'up',
#  Timestamp('2014-09-15 10:00:00'): 'down',
#  Timestamp('2014-09-16 01:00:00'): 'up',
#  Timestamp('2014-09-16 03:00:00'): 'down',
#  Timestamp('2014-09-16 10:00:00'): 'up',
#  Timestamp('2014-09-16 19:00:00'): 'down',
#  Timestamp('2014-09-17 00:00:00'): 'up',
#  Timestamp('2014-09-17 14:00:00'): 'down',
#  Timestamp('2014-09-18 00:00:00'): 'up',
#  Timestamp('2014-09-19 05:00:00'): 'down',
#  Timestamp('2014-09-19 22:00:00'): 'up',
#  Timestamp('2014-09-22 04:00:00'): 'down',
#  Timestamp('2014-09-22 12:00:00'): 'up',
#  Timestamp('2014-09-23 05:00:00'): 'down',
#  Timestamp('2014-09-23 09:00:00'): 'up',
#  Timestamp('2014-09-23 13:00:00'): 'down',
#  Timestamp('2014-09-23 18:00:00'): 'up',
#  Timestamp('2014-09-24 05:00:00'): 'down',
#  Timestamp('2014-09-25 13:00:00'): 'up',
#  Timestamp('2014-09-25 15:00:00'): 'down',
#  Timestamp('2014-09-25 18:00:00'): 'up',
#  Timestamp('2014-09-26 01:00:00'): 'down',
#  Timestamp('2014-09-26 07:00:00'): 'up',
#  Timestamp('2014-09-26 10:00:00'): 'down',
#  Timestamp('2014-09-29 07:00:00'): 'up',
#  Timestamp('2014-09-29 17:00:00'): 'down',
#  Timestamp('2014-09-30 02:00:00'): 'up',
#  Timestamp('2014-09-30 08:00:00'): 'down',
#  Timestamp('2014-09-30 12:00:00'): 'up',
#  Timestamp('2014-09-30 19:00:00'): 'down',
#  Timestamp('2014-10-01 10:00:00'): 'up',
#  Timestamp('2014-10-01 15:00:00'): 'down',
#  Timestamp('2014-10-01 20:00:00'): 'up',
#  Timestamp('2014-10-02 06:00:00'): 'down',
#  Timestamp('2014-10-02 16:00:00'): 'up',
#  Timestamp('2014-10-03 01:00:00'): 'down',
#  Timestamp('2014-10-06 00:00:00'): 'up',
#  Timestamp('2014-10-06 22:00:00'): 'down',
#  Timestamp('2014-10-07 04:00:00'): 'up',
#  Timestamp('2014-10-07 20:00:00'): 'down',
#  Timestamp('2014-10-08 19:00:00'): 'up',
#  Timestamp('2014-10-09 12:00:00'): 'down',
#  Timestamp('2014-10-09 22:00:00'): 'up',
#  Timestamp('2014-10-10 03:00:00'): 'down',
#  Timestamp('2014-10-10 14:00:00'): 'up',
#  Timestamp('2014-10-13 03:00:00'): 'down',
#  Timestamp('2014-10-13 16:00:00'): 'up',
#  Timestamp('2014-10-13 22:00:00'): 'down',
#  Timestamp('2014-10-15 02:00:00'): 'up',
#  Timestamp('2014-10-15 22:00:00'): 'down',
#  Timestamp('2014-10-16 11:00:00'): 'up',
#  Timestamp('2014-10-17 01:00:00'): 'down',
#  Timestamp('2014-10-17 08:00:00'): 'up',
#  Timestamp('2014-10-17 13:00:00'): 'down',
#  Timestamp('2014-10-17 15:00:00'): 'up',
#  Timestamp('2014-10-17 20:00:00'): 'down',
#  Timestamp('2014-10-20 08:00:00'): 'up',
#  Timestamp('2014-10-20 21:00:00'): 'down',
#  Timestamp('2014-10-21 01:00:00'): 'up',
#  Timestamp('2014-10-21 06:00:00'): 'down',
#  Timestamp('2014-10-22 00:00:00'): 'up',
#  Timestamp('2014-10-22 06:00:00'): 'down',
#  Timestamp('2014-10-22 14:00:00'): 'up',
#  Timestamp('2014-10-22 18:00:00'): 'down',
#  Timestamp('2014-10-23 02:00:00'): 'up',
#  Timestamp('2014-10-23 06:00:00'): 'down',
#  Timestamp('2014-10-23 12:00:00'): 'up',
#  Timestamp('2014-10-23 17:00:00'): 'down',
#  Timestamp('2014-10-23 21:00:00'): 'up',
#  Timestamp('2014-10-27 15:00:00'): 'down',
#  Timestamp('2014-10-27 23:00:00'): 'up',
#  Timestamp('2014-10-28 05:00:00'): 'down',
#  Timestamp('2014-10-28 09:00:00'): 'up',
#  Timestamp('2014-10-28 14:00:00'): 'down',
#  Timestamp('2014-10-28 21:00:00'): 'up',
#  Timestamp('2014-10-29 07:00:00'): 'down',
#  Timestamp('2014-10-29 13:00:00'): 'up',
#  Timestamp('2014-10-29 16:00:00'): 'down',
#  Timestamp('2014-10-30 06:00:00'): 'up',
#  Timestamp('2014-10-30 17:00:00'): 'down',
#  Timestamp('2014-10-31 07:00:00'): 'up',
#  Timestamp('2014-10-31 12:00:00'): 'down',
#  Timestamp('2014-10-31 14:00:00'): 'up',
#  Timestamp('2014-10-31 16:00:00'): 'down',
#  Timestamp('2014-11-03 01:00:00'): 'up',
#  Timestamp('2014-11-03 10:00:00'): 'down',
#  Timestamp('2014-11-03 22:00:00'): 'up',
#  Timestamp('2014-11-04 15:00:00'): 'down',
#  Timestamp('2014-11-04 17:00:00'): 'up',
#  Timestamp('2014-11-05 05:00:00'): 'down',
#  Timestamp('2014-11-05 11:00:00'): 'up',
#  Timestamp('2014-11-05 17:00:00'): 'down',
#  Timestamp('2014-11-06 01:00:00'): 'up',
#  Timestamp('2014-11-06 07:00:00'): 'down',
#  Timestamp('2014-11-07 10:00:00'): 'up',
#  Timestamp('2014-11-10 11:00:00'): 'down',
#  Timestamp('2014-11-11 05:00:00'): 'up',
#  Timestamp('2014-11-12 00:00:00'): 'down',
#  Timestamp('2014-11-12 05:00:00'): 'up',
#  Timestamp('2014-11-12 08:00:00'): 'down',
#  Timestamp('2014-11-14 15:00:00'): 'up',
#  Timestamp('2014-11-17 05:00:00'): 'down',
#  Timestamp('2014-11-17 23:00:00'): 'up',
#  Timestamp('2014-11-18 12:00:00'): 'down',
#  Timestamp('2014-11-19 09:00:00'): 'up',
#  Timestamp('2014-11-19 19:00:00'): 'down',
#  Timestamp('2014-11-20 08:00:00'): 'up',
#  Timestamp('2014-11-20 15:00:00'): 'down',
#  Timestamp('2014-11-21 01:00:00'): 'up',
#  Timestamp('2014-11-21 02:00:00'): 'down',
#  Timestamp('2014-11-21 22:00:00'): 'up',
#  Timestamp('2014-11-24 08:00:00'): 'down',
#  Timestamp('2014-11-24 10:00:00'): 'up',
#  Timestamp('2014-11-25 00:00:00'): 'down',
#  Timestamp('2014-11-25 14:00:00'): 'up',
#  Timestamp('2014-11-26 01:00:00'): 'down',
#  Timestamp('2014-11-26 06:00:00'): 'up',
#  Timestamp('2014-11-26 20:00:00'): 'down',
#  Timestamp('2014-11-27 03:00:00'): 'up',
#  Timestamp('2014-11-27 09:00:00'): 'down',
#  Timestamp('2014-12-01 02:00:00'): 'up',
#  Timestamp('2014-12-01 19:00:00'): 'down',
#  Timestamp('2014-12-02 23:00:00'): 'up',
#  Timestamp('2014-12-03 17:00:00'): 'down',
#  Timestamp('2014-12-04 00:00:00'): 'up',
#  Timestamp('2014-12-04 02:00:00'): 'down',
#  Timestamp('2014-12-04 14:00:00'): 'up',
#  Timestamp('2014-12-04 18:00:00'): 'down',
#  Timestamp('2014-12-05 07:00:00'): 'up',
#  Timestamp('2014-12-05 14:00:00'): 'down',
#  Timestamp('2014-12-08 09:00:00'): 'up',
#  Timestamp('2014-12-08 20:00:00'): 'down',
#  Timestamp('2014-12-09 05:00:00'): 'up',
#  Timestamp('2014-12-09 09:00:00'): 'down',
#  Timestamp('2014-12-09 13:00:00'): 'up',
#  Timestamp('2014-12-09 18:00:00'): 'down',
#  Timestamp('2014-12-10 12:00:00'): 'up',
#  Timestamp('2014-12-11 02:00:00'): 'down',
#  Timestamp('2014-12-11 12:00:00'): 'up',
#  Timestamp('2014-12-12 07:00:00'): 'down',
#  Timestamp('2014-12-12 10:00:00'): 'up',
#  Timestamp('2014-12-12 18:00:00'): 'down',
#  Timestamp('2014-12-12 21:00:00'): 'up',
#  Timestamp('2014-12-15 00:00:00'): 'down',
#  Timestamp('2014-12-15 04:00:00'): 'up',
#  Timestamp('2014-12-15 08:00:00'): 'down',
#  Timestamp('2014-12-15 23:00:00'): 'up',
#  Timestamp('2014-12-16 15:00:00'): 'down',
#  Timestamp('2014-12-16 21:00:00'): 'up',
#  Timestamp('2014-12-16 23:00:00'): 'down',
#  Timestamp('2014-12-18 00:00:00'): 'up',
#  Timestamp('2014-12-18 22:00:00'): 'down',
#  Timestamp('2014-12-19 23:00:00'): 'up',
#  Timestamp('2014-12-22 09:00:00'): 'down',
#  Timestamp('2014-12-23 01:00:00'): 'up',
#  Timestamp('2014-12-23 05:00:00'): 'down',
#  Timestamp('2014-12-24 04:00:00'): 'up',
#  Timestamp('2014-12-26 17:00:00'): 'down',
#  Timestamp('2014-12-26 23:00:00'): 'up',
#  Timestamp('2014-12-29 06:00:00'): 'down',
#  Timestamp('2014-12-30 08:00:00'): 'up',
#  Timestamp('2014-12-31 03:00:00'): 'down',
#  Timestamp('2014-12-31 08:00:00'): 'up',
#  Timestamp('2014-12-31 13:00:00'): 'down',
#  Timestamp('2015-01-05 15:00:00'): 'up',
#  Timestamp('2015-01-06 02:00:00'): 'down',
#  Timestamp('2015-01-07 17:00:00'): 'up',
#  Timestamp('2015-01-07 21:00:00'): 'down',
#  Timestamp('2015-01-08 10:00:00'): 'up',
#  Timestamp('2015-01-08 18:00:00'): 'down',
#  Timestamp('2015-01-09 00:00:00'): 'up',
#  Timestamp('2015-01-12 00:00:00'): 'down',
#  Timestamp('2015-01-12 10:00:00'): 'up',
#  Timestamp('2015-01-12 20:00:00'): 'down',
#  Timestamp('2015-01-13 11:00:00'): 'up',
#  Timestamp('2015-01-13 17:00:00'): 'down',
#  Timestamp('2015-01-13 21:00:00'): 'up',
#  Timestamp('2015-01-14 02:00:00'): 'down',
#  Timestamp('2015-01-14 08:00:00'): 'up',
#  Timestamp('2015-01-15 14:00:00'): 'down',
#  Timestamp('2015-01-15 19:00:00'): 'up',
#  Timestamp('2015-01-16 11:00:00'): 'down',
#  Timestamp('2015-01-16 17:00:00'): 'up',
#  Timestamp('2015-01-16 21:00:00'): 'down',
#  Timestamp('2015-01-19 09:00:00'): 'up',
#  Timestamp('2015-01-19 11:00:00'): 'down',
#  Timestamp('2015-01-20 06:00:00'): 'up',
#  Timestamp('2015-01-20 15:00:00'): 'down',
#  Timestamp('2015-01-21 02:00:00'): 'up',
#  Timestamp('2015-01-21 08:00:00'): 'down',
#  Timestamp('2015-01-21 19:00:00'): 'up',
#  Timestamp('2015-01-22 03:00:00'): 'down',
#  Timestamp('2015-01-22 08:00:00'): 'up',
#  Timestamp('2015-01-22 14:00:00'): 'down',
#  Timestamp('2015-01-23 13:00:00'): 'up',
#  Timestamp('2015-01-23 17:00:00'): 'down',
#  Timestamp('2015-01-26 04:00:00'): 'up',
#  Timestamp('2015-01-27 20:00:00'): 'down',
#  Timestamp('2015-01-28 03:00:00'): 'up',
#  Timestamp('2015-01-28 12:00:00'): 'down',
#  Timestamp('2015-01-29 18:00:00'): 'up',
#  Timestamp('2015-01-30 07:00:00'): 'down',
#  Timestamp('2015-01-30 17:00:00'): 'up',
#  Timestamp('2015-01-30 23:00:00'): 'down',
#  Timestamp('2015-02-02 12:00:00'): 'up',
#  Timestamp('2015-02-02 16:00:00'): 'down',
#  Timestamp('2015-02-02 22:00:00'): 'up',
#  Timestamp('2015-02-03 03:00:00'): 'down',
#  Timestamp('2015-02-03 09:00:00'): 'up',
#  Timestamp('2015-02-03 22:00:00'): 'down',
#  Timestamp('2015-02-04 01:00:00'): 'up',
#  Timestamp('2015-02-04 14:00:00'): 'down',
#  Timestamp('2015-02-05 02:00:00'): 'up',
#  Timestamp('2015-02-06 07:00:00'): 'down',
#  Timestamp('2015-02-06 20:00:00'): 'up',
#  Timestamp('2015-02-09 09:00:00'): 'down',
# ...
#  Timestamp('2021-02-19 05:00:00'): 'up',
#  Timestamp('2021-02-19 15:00:00'): 'down',
#  Timestamp('2021-02-19 23:00:00'): 'up',
#  Timestamp('2021-02-22 03:00:00'): 'down',
#  Timestamp('2021-02-22 09:00:00'): 'up',
#  Timestamp('2021-02-24 08:00:00'): 'down',
#  Timestamp('2021-02-24 19:00:00'): 'up',
#  Timestamp('2021-02-25 11:00:00'): 'down',
#  Timestamp('2021-02-26 12:00:00'): 'up',
#  Timestamp('2021-02-26 17:00:00'): 'down',
#  Timestamp('2021-02-26 23:00:00'): 'up',
#  Timestamp('2021-03-01 08:00:00'): 'down',
#  Timestamp('2021-03-02 11:00:00'): 'up',
#  Timestamp('2021-03-02 20:00:00'): 'down',
#  Timestamp('2021-03-02 23:00:00'): 'up',
#  Timestamp('2021-03-03 12:00:00'): 'down',
#  Timestamp('2021-03-03 16:00:00'): 'up',
#  Timestamp('2021-03-03 18:00:00'): 'down',
#  Timestamp('2021-03-04 01:00:00'): 'up',
#  Timestamp('2021-03-04 08:00:00'): 'down',
#  Timestamp('2021-03-04 11:00:00'): 'up',
#  Timestamp('2021-03-04 18:00:00'): 'down',
#  Timestamp('2021-03-05 23:00:00'): 'up',
#  Timestamp('2021-03-08 02:00:00'): 'down',
#  Timestamp('2021-03-08 08:00:00'): 'up',
#  Timestamp('2021-03-08 15:00:00'): 'down',
#  Timestamp('2021-03-09 03:00:00'): 'up',
#  Timestamp('2021-03-09 21:00:00'): 'down',
#  Timestamp('2021-03-10 07:00:00'): 'up',
#  Timestamp('2021-03-12 02:00:00'): 'down',
#  Timestamp('2021-03-12 13:00:00'): 'up',
#  Timestamp('2021-03-15 03:00:00'): 'down',
#  Timestamp('2021-03-15 07:00:00'): 'up',
#  Timestamp('2021-03-15 10:00:00'): 'down',
#  Timestamp('2021-03-15 17:00:00'): 'up',
#  Timestamp('2021-03-15 22:00:00'): 'down',
#  Timestamp('2021-03-16 10:00:00'): 'up',
#  Timestamp('2021-03-17 01:00:00'): 'down',
#  Timestamp('2021-03-17 07:00:00'): 'up',
#  Timestamp('2021-03-17 09:00:00'): 'down',
#  Timestamp('2021-03-17 19:00:00'): 'up',
#  Timestamp('2021-03-18 01:00:00'): 'down',
#  Timestamp('2021-03-18 05:00:00'): 'up',
#  Timestamp('2021-03-18 12:00:00'): 'down',
#  Timestamp('2021-03-19 02:00:00'): 'up',
#  Timestamp('2021-03-19 10:00:00'): 'down',
#  Timestamp('2021-03-22 03:00:00'): 'up',
#  Timestamp('2021-03-22 13:00:00'): 'down',
#  Timestamp('2021-03-22 15:00:00'): 'up',
#  Timestamp('2021-03-22 19:00:00'): 'down',
#  Timestamp('2021-03-24 09:00:00'): 'up',
#  Timestamp('2021-03-24 17:00:00'): 'down',
#  Timestamp('2021-03-25 00:00:00'): 'up',
#  Timestamp('2021-03-25 04:00:00'): 'down',
#  Timestamp('2021-03-25 09:00:00'): 'up',
#  Timestamp('2021-03-29 01:00:00'): 'down',
#  Timestamp('2021-03-29 08:00:00'): 'up',
#  Timestamp('2021-03-29 14:00:00'): 'down',
#  Timestamp('2021-03-29 23:00:00'): 'up',
#  Timestamp('2021-03-30 07:00:00'): 'down',
#  Timestamp('2021-03-30 20:00:00'): 'up',
#  Timestamp('2021-03-31 02:00:00'): 'down',
#  Timestamp('2021-03-31 05:00:00'): 'up',
#  Timestamp('2021-03-31 19:00:00'): 'down',
#  Timestamp('2021-04-01 08:00:00'): 'up',
#  Timestamp('2021-04-02 08:00:00'): 'down',
#  Timestamp('2021-04-05 00:00:00'): 'up',
#  Timestamp('2021-04-06 08:00:00'): 'down',
#  Timestamp('2021-04-07 00:00:00'): 'up',
#  Timestamp('2021-04-07 03:00:00'): 'down',
#  Timestamp('2021-04-07 22:00:00'): 'up',
#  Timestamp('2021-04-08 09:00:00'): 'down',
#  Timestamp('2021-04-08 22:00:00'): 'up',
#  Timestamp('2021-04-09 03:00:00'): 'down',
#  Timestamp('2021-04-09 09:00:00'): 'up',
#  Timestamp('2021-04-09 16:00:00'): 'down',
#  Timestamp('2021-04-12 07:00:00'): 'up',
#  Timestamp('2021-04-12 15:00:00'): 'down',
#  Timestamp('2021-04-12 22:00:00'): 'up',
#  Timestamp('2021-04-13 02:00:00'): 'down',
#  Timestamp('2021-04-13 07:00:00'): 'up',
#  Timestamp('2021-04-13 12:00:00'): 'down',
#  Timestamp('2021-04-13 14:00:00'): 'up',
#  Timestamp('2021-04-14 09:00:00'): 'down',
#  Timestamp('2021-04-14 15:00:00'): 'up',
#  Timestamp('2021-04-14 19:00:00'): 'down',
#  Timestamp('2021-04-15 13:00:00'): 'up',
#  Timestamp('2021-04-15 21:00:00'): 'down',
#  Timestamp('2021-04-16 09:00:00'): 'up',
#  Timestamp('2021-04-16 23:00:00'): 'down',
#  Timestamp('2021-04-19 03:00:00'): 'up',
#  Timestamp('2021-04-20 09:00:00'): 'down',
#  Timestamp('2021-04-21 07:00:00'): 'up',
#  Timestamp('2021-04-21 09:00:00'): 'down',
#  Timestamp('2021-04-21 16:00:00'): 'up',
#  Timestamp('2021-04-22 05:00:00'): 'down',
#  Timestamp('2021-04-22 20:00:00'): 'up',
#  Timestamp('2021-04-23 13:00:00'): 'down',
#  Timestamp('2021-04-23 17:00:00'): 'up',
#  Timestamp('2021-04-26 10:00:00'): 'down',
#  Timestamp('2021-04-26 15:00:00'): 'up',
#  Timestamp('2021-04-26 22:00:00'): 'down',
#  Timestamp('2021-04-27 11:00:00'): 'up',
#  Timestamp('2021-04-27 17:00:00'): 'down',
#  Timestamp('2021-04-28 13:00:00'): 'up',
#  Timestamp('2021-04-29 04:00:00'): 'down',
#  Timestamp('2021-04-29 23:00:00'): 'up',
#  Timestamp('2021-04-30 04:00:00'): 'down',
#  Timestamp('2021-04-30 20:00:00'): 'up',
#  Timestamp('2021-05-03 21:00:00'): 'down',
#  Timestamp('2021-05-04 15:00:00'): 'up',
#  Timestamp('2021-05-05 06:00:00'): 'down',
#  Timestamp('2021-05-05 11:00:00'): 'up',
#  Timestamp('2021-05-05 18:00:00'): 'down',
#  Timestamp('2021-05-05 19:00:00'): 'up',
#  Timestamp('2021-05-05 22:00:00'): 'down',
#  Timestamp('2021-05-06 06:00:00'): 'up',
#  Timestamp('2021-05-06 12:00:00'): 'down',
#  Timestamp('2021-05-06 18:00:00'): 'up',
#  Timestamp('2021-05-10 18:00:00'): 'down',
#  Timestamp('2021-05-11 09:00:00'): 'up',
#  Timestamp('2021-05-11 19:00:00'): 'down',
#  Timestamp('2021-05-12 06:00:00'): 'up',
#  Timestamp('2021-05-12 13:00:00'): 'down',
#  Timestamp('2021-05-12 23:00:00'): 'up',
#  Timestamp('2021-05-13 04:00:00'): 'down',
#  Timestamp('2021-05-13 20:00:00'): 'up',
#  Timestamp('2021-05-14 01:00:00'): 'down',
#  Timestamp('2021-05-14 05:00:00'): 'up',
#  Timestamp('2021-05-17 02:00:00'): 'down',
#  Timestamp('2021-05-17 07:00:00'): 'up',
#  Timestamp('2021-05-18 17:00:00'): 'down',
#  Timestamp('2021-05-20 05:00:00'): 'up',
#  Timestamp('2021-05-20 22:00:00'): 'down',
#  Timestamp('2021-05-21 06:00:00'): 'up',
#  Timestamp('2021-05-21 13:00:00'): 'down',
#  Timestamp('2021-05-24 02:00:00'): 'up',
#  Timestamp('2021-05-24 10:00:00'): 'down',
#  Timestamp('2021-05-24 14:00:00'): 'up',
#  Timestamp('2021-05-25 09:00:00'): 'down',
#  Timestamp('2021-05-25 18:00:00'): 'up',
#  Timestamp('2021-05-26 13:00:00'): 'down',
#  Timestamp('2021-05-27 04:00:00'): 'up',
#  Timestamp('2021-05-27 21:00:00'): 'down',
#  Timestamp('2021-05-28 15:00:00'): 'up',
#  Timestamp('2021-05-28 19:00:00'): 'down',
#  Timestamp('2021-05-31 02:00:00'): 'up',
#  Timestamp('2021-05-31 05:00:00'): 'down',
#  Timestamp('2021-05-31 11:00:00'): 'up',
#  Timestamp('2021-06-01 04:00:00'): 'down',
#  Timestamp('2021-06-01 23:00:00'): 'up',
#  Timestamp('2021-06-02 05:00:00'): 'down',
#  Timestamp('2021-06-02 13:00:00'): 'up',
#  Timestamp('2021-06-02 18:00:00'): 'down',
#  Timestamp('2021-06-03 00:00:00'): 'up',
#  Timestamp('2021-06-03 03:00:00'): 'down',
#  Timestamp('2021-06-03 10:00:00'): 'up',
#  Timestamp('2021-06-03 12:00:00'): 'down',
#  Timestamp('2021-06-03 20:00:00'): 'up',
#  Timestamp('2021-06-04 01:00:00'): 'down',
#  Timestamp('2021-06-04 08:00:00'): 'up',
#  Timestamp('2021-06-04 16:00:00'): 'down',
#  Timestamp('2021-06-07 09:00:00'): 'up',
#  Timestamp('2021-06-07 20:00:00'): 'down',
#  Timestamp('2021-06-08 16:00:00'): 'up',
#  Timestamp('2021-06-09 11:00:00'): 'down',
#  Timestamp('2021-06-10 03:00:00'): 'up',
#  Timestamp('2021-06-10 04:00:00'): 'down',
#  Timestamp('2021-06-10 10:00:00'): 'up',
#  Timestamp('2021-06-11 07:00:00'): 'down',
#  Timestamp('2021-06-11 23:00:00'): 'up',
#  Timestamp('2021-06-14 02:00:00'): 'down',
#  Timestamp('2021-06-14 11:00:00'): 'up',
#  Timestamp('2021-06-14 17:00:00'): 'down',
#  Timestamp('2021-06-15 04:00:00'): 'up',
#  Timestamp('2021-06-15 08:00:00'): 'down',
#  Timestamp('2021-06-15 14:00:00'): 'up',
#  Timestamp('2021-06-15 23:00:00'): 'down',
#  Timestamp('2021-06-16 03:00:00'): 'up',
#  Timestamp('2021-06-16 15:00:00'): 'down',
#  Timestamp('2021-06-17 03:00:00'): 'up',
#  Timestamp('2021-06-17 08:00:00'): 'down',
#  Timestamp('2021-06-17 19:00:00'): 'up',
#  Timestamp('2021-06-18 04:00:00'): 'down',
#  Timestamp('2021-06-18 23:00:00'): 'up',
#  Timestamp('2021-06-21 03:00:00'): 'down',
#  Timestamp('2021-06-21 06:00:00'): 'up',
#  Timestamp('2021-06-22 00:00:00'): 'down',
#  Timestamp('2021-06-22 11:00:00'): 'up',
#  Timestamp('2021-06-23 02:00:00'): 'down',
#  Timestamp('2021-06-23 04:00:00'): 'up',
#  Timestamp('2021-06-23 16:00:00'): 'down',
#  Timestamp('2021-06-24 06:00:00'): 'up',
#  Timestamp('2021-06-24 13:00:00'): 'down',
#  Timestamp('2021-06-24 17:00:00'): 'up',
#  Timestamp('2021-06-25 04:00:00'): 'down',
#  Timestamp('2021-06-25 23:00:00'): 'up',
#  Timestamp('2021-06-28 10:00:00'): 'down',
#  Timestamp('2021-06-29 15:00:00'): 'up',
#  Timestamp('2021-06-30 04:00:00'): 'down',
#  Timestamp('2021-06-30 10:00:00'): 'up',
#  Timestamp('2021-06-30 14:00:00'): 'down',
#  Timestamp('2021-06-30 19:00:00'): 'up',
#  Timestamp('2021-06-30 22:00:00'): 'down',
#  Timestamp('2021-07-01 21:00:00'): 'up',
#  Timestamp('2021-07-02 07:00:00'): 'down',
#  Timestamp('2021-07-02 13:00:00'): 'up',
#  Timestamp('2021-07-02 21:00:00'): 'down',
#  Timestamp('2021-07-05 08:00:00'): 'up',
#  Timestamp('2021-07-05 13:00:00'): 'down',
#  Timestamp('2021-07-05 17:00:00'): 'up',
#  Timestamp('2021-07-06 09:00:00'): 'down',
#  Timestamp('2021-07-07 11:00:00'): 'up',
#  Timestamp('2021-07-07 14:00:00'): 'down',
#  Timestamp('2021-07-07 17:00:00'): 'up',
#  Timestamp('2021-07-08 01:00:00'): 'down',
#  Timestamp('2021-07-08 17:00:00'): 'up',
#  Timestamp('2021-07-09 02:00:00'): 'down',
#  Timestamp('2021-07-09 09:00:00'): 'up',
#  Timestamp('2021-07-12 04:00:00'): 'down',
#  Timestamp('2021-07-12 14:00:00'): 'up',
#  Timestamp('2021-07-13 05:00:00'): 'down',
#  Timestamp('2021-07-14 02:00:00'): 'up',
#  Timestamp('2021-07-14 15:00:00'): 'down',
#  Timestamp('2021-07-15 10:00:00'): 'up',
#  Timestamp('2021-07-15 14:00:00'): 'down',
#  Timestamp('2021-07-15 20:00:00'): 'up',
#  Timestamp('2021-07-16 11:00:00'): 'down',
#  Timestamp('2021-07-19 21:00:00'): 'up',
#  Timestamp('2021-07-20 04:00:00'): 'down',
#  Timestamp('2021-07-20 15:00:00'): 'up',
#  Timestamp('2021-07-21 02:00:00'): 'down',
#  Timestamp('2021-07-21 08:00:00'): 'up',
#  Timestamp('2021-07-21 22:00:00'): 'down',
#  Timestamp('2021-07-22 03:00:00'): 'up',
#  Timestamp('2021-07-23 03:00:00'): 'down',
#  Timestamp('2021-07-23 11:00:00'): 'up',
#  Timestamp('2021-07-23 20:00:00'): 'down',
#  Timestamp('2021-07-26 05:00:00'): 'up',
#  Timestamp('2021-07-26 18:00:00'): 'down',
#  Timestamp('2021-07-26 21:00:00'): 'up',
#  Timestamp('2021-07-27 06:00:00'): 'down',
#  Timestamp('2021-07-27 12:00:00'): 'up',
#  Timestamp('2021-07-27 20:00:00'): 'down',
#  Timestamp('2021-07-28 07:00:00'): 'up',
#  Timestamp('2021-07-28 11:00:00'): 'down',
#  Timestamp('2021-07-28 16:00:00'): 'up',
#  Timestamp('2021-07-29 16:00:00'): 'down',
#  Timestamp('2021-07-30 08:00:00'): 'up',
#  Timestamp('2021-07-30 11:00:00'): 'down',
#  Timestamp('2021-08-02 00:00:00'): 'up',
#  Timestamp('2021-08-02 11:00:00'): 'down',
#  Timestamp('2021-08-03 00:00:00'): 'up',
#  Timestamp('2021-08-03 13:00:00'): 'down',
#  Timestamp('2021-08-03 16:00:00'): 'up',
#  Timestamp('2021-08-04 16:00:00'): 'down',
#  Timestamp('2021-08-05 05:00:00'): 'up',
#  Timestamp('2021-08-05 20:00:00'): 'down',
#  Timestamp('2021-08-09 11:00:00'): 'up',
#  Timestamp('2021-08-09 12:00:00'): 'down',
#  Timestamp('2021-08-10 04:00:00'): 'up',
#  Timestamp('2021-08-10 11:00:00'): 'down',
#  Timestamp('2021-08-11 11:00:00'): 'up',
#  Timestamp('2021-08-11 19:00:00'): 'down',
#  Timestamp('2021-08-12 02:00:00'): 'up',
#  Timestamp('2021-08-12 10:00:00'): 'down',
#  Timestamp('2021-08-12 21:00:00'): 'up',
#  Timestamp('2021-08-13 07:00:00'): 'down',
#  Timestamp('2021-08-13 13:00:00'): 'up',
#  Timestamp('2021-08-13 20:00:00'): 'down',
#  Timestamp('2021-08-16 09:00:00'): 'up',
#  Timestamp('2021-08-16 14:00:00'): 'down',
#  Timestamp('2021-08-17 19:00:00'): 'up',
#  Timestamp('2021-08-18 16:00:00'): 'down',
#  Timestamp('2021-08-20 15:00:00'): 'up',
#  Timestamp('2021-08-23 21:00:00'): 'down',
#  Timestamp('2021-08-24 04:00:00'): 'up',
#  Timestamp('2021-08-24 08:00:00'): 'down',
#  Timestamp('2021-08-24 11:00:00'): 'up',
#  Timestamp('2021-08-24 22:00:00'): 'down',
#  Timestamp('2021-08-25 09:00:00'): 'up',
#  Timestamp('2021-08-25 11:00:00'): 'down',
#  Timestamp('2021-08-25 15:00:00'): 'up',
#  Timestamp('2021-08-26 02:00:00'): 'down',
#  Timestamp('2021-08-27 03:00:00'): 'up',
#  Timestamp('2021-08-27 19:00:00'): 'down',
#  Timestamp('2021-08-27 23:00:00'): 'up',
#  Timestamp('2021-08-30 07:00:00'): 'down',
#  Timestamp('2021-08-30 15:00:00'): 'up',
#  Timestamp('2021-08-31 08:00:00'): 'down',
#  Timestamp('2021-09-01 07:00:00'): 'up',
#  Timestamp('2021-09-01 16:00:00'): 'down',
#  Timestamp('2021-09-01 23:00:00'): 'up',
#  Timestamp('2021-09-03 03:00:00'): 'down',
#  Timestamp('2021-09-03 13:00:00'): 'up',
#  Timestamp('2021-09-03 20:00:00'): 'down',
#  Timestamp('2021-09-06 18:00:00'): 'up',
#  Timestamp('2021-09-07 05:00:00'): 'down',
#  Timestamp('2021-09-07 17:00:00'): 'up',
#  Timestamp('2021-09-07 20:00:00'): 'down',
#  Timestamp('2021-09-08 17:00:00'): 'up',
#  Timestamp('2021-09-08 21:00:00'): 'down',
#  Timestamp('2021-09-09 08:00:00'): 'up',
#  Timestamp('2021-09-09 19:00:00'): 'down',
#  Timestamp('2021-09-09 23:00:00'): 'up',
#  Timestamp('2021-09-10 14:00:00'): 'down',
#  Timestamp('2021-09-13 09:00:00'): 'up',
#  Timestamp('2021-09-13 17:00:00'): 'down',
#  Timestamp('2021-09-13 21:00:00'): 'up',
#  Timestamp('2021-09-14 15:00:00'): 'down',
#  Timestamp('2021-09-15 05:00:00'): 'up',
#  Timestamp('2021-09-16 01:00:00'): 'down',
#  Timestamp('2021-09-16 17:00:00'): 'up',
#  Timestamp('2021-09-17 08:00:00'): 'down',
#  Timestamp('2021-09-20 19:00:00'): 'up',
#  Timestamp('2021-09-21 12:00:00'): 'down',
#  Timestamp('2021-09-21 20:00:00'): 'up',
#  Timestamp('2021-09-22 04:00:00'): 'down',
#  Timestamp('2021-09-22 15:00:00'): 'up',
#  Timestamp('2021-09-22 18:00:00'): 'down',
#  Timestamp('2021-09-23 02:00:00'): 'up',
#  Timestamp('2021-09-23 20:00:00'): 'down',
#  Timestamp('2021-09-27 00:00:00'): 'up',
#  Timestamp('2021-09-27 16:00:00'): 'down',
#  Timestamp('2021-09-28 04:00:00'): 'up',
#  Timestamp('2021-09-28 07:00:00'): 'down',
#  Timestamp('2021-09-28 20:00:00'): 'up',
#  Timestamp('2021-09-29 07:00:00'): 'down',
#  Timestamp('2021-09-29 22:00:00'): 'up',
#  Timestamp('2021-09-30 06:00:00'): 'down',
#  Timestamp('2021-09-30 13:00:00'): 'up',
#  Timestamp('2021-10-01 01:00:00'): 'down',
#  Timestamp('2021-10-01 08:00:00'): 'up',
#  Timestamp('2021-10-01 18:00:00'): 'down',
#  Timestamp('2021-10-04 06:00:00'): 'up',
#  Timestamp('2021-10-04 21:00:00'): 'down',
#  Timestamp('2021-10-05 07:00:00'): 'up',
#  Timestamp('2021-10-05 19:00:00'): 'down',
#  Timestamp('2021-10-06 13:00:00'): 'up',
#  Timestamp('2021-10-07 03:00:00'): 'down',
#  Timestamp('2021-10-07 08:00:00'): 'up',
#  Timestamp('2021-10-07 18:00:00'): 'down',
#  Timestamp('2021-10-08 10:00:00'): 'up',
#  Timestamp('2021-10-08 15:00:00'): 'down',
#  Timestamp('2021-10-11 00:00:00'): 'up',
#  Timestamp('2021-10-11 09:00:00'): 'down',
#  Timestamp('2021-10-12 10:00:00'): 'up',
#  Timestamp('2021-10-12 14:00:00'): 'down',
#  Timestamp('2021-10-13 02:00:00'): 'up',
#  Timestamp('2021-10-14 12:00:00'): 'down',
#  Timestamp('2021-10-15 02:00:00'): 'up',
#  Timestamp('2021-10-15 17:00:00'): 'down',
#  Timestamp('2021-10-18 17:00:00'): 'up',
#  Timestamp('2021-10-18 20:00:00'): 'down',
#  Timestamp('2021-10-18 23:00:00'): 'up',
#  Timestamp('2021-10-19 13:00:00'): 'down',
#  Timestamp('2021-10-20 00:00:00'): 'up',
#  Timestamp('2021-10-20 07:00:00'): 'down',
#  Timestamp('2021-10-20 14:00:00'): 'up',
#  Timestamp('2021-10-20 21:00:00'): 'down',
#  Timestamp('2021-10-20 23:00:00'): 'up',
#  Timestamp('2021-10-21 06:00:00'): 'down',
#  Timestamp('2021-10-21 12:00:00'): 'up',
#  Timestamp('2021-10-21 17:00:00'): 'down',
#  Timestamp('2021-10-21 20:00:00'): 'up',
#  Timestamp('2021-10-22 11:00:00'): 'down',
#  Timestamp('2021-10-22 23:00:00'): 'up',
#  Timestamp('2021-10-25 10:00:00'): 'down',
#  Timestamp('2021-10-25 15:00:00'): 'up',
#  Timestamp('2021-10-25 21:00:00'): 'down',
#  Timestamp('2021-10-26 08:00:00'): 'up',
#  Timestamp('2021-10-26 13:00:00'): 'down',
#  Timestamp('2021-10-27 00:00:00'): 'up',
#  Timestamp('2021-10-27 07:00:00'): 'down',
#  Timestamp('2021-10-27 13:00:00'): 'up',
#  Timestamp('2021-10-27 20:00:00'): 'down',
#  Timestamp('2021-10-28 03:00:00'): 'up',
#  Timestamp('2021-10-29 01:00:00'): 'down',
#  Timestamp('2021-11-01 12:00:00'): 'up',
#  Timestamp('2021-11-01 14:00:00'): 'down'}
